# %%
# multidimensional arrays
import numpy as np

# inline plots
import matplotlib.pyplot as plt
# %matplotlib inline

#benchmarking
import time

# nicer figures
import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %% [markdown]
# # Return to the origin
#
#
# For a *finite* random walk of (large) length $n$, it is known that the expected number of returns to the origin $T_n$ scales like follows:
# $$
# \left\langle T_n \right\rangle \sim \left\{
# \begin{array}{ll}
# \sqrt{n} & d=1 \\
# \log(n) & d=2 \\
# C_d & d\geq 3
# \end{array}
# \right.
# $$
#
#
# <img src="attachment:image.png" width="600">
#
# Notice that for $d \geq 3$, $\left\langle T_n \right\rangle$ does **not** grow with $n$, which must mean that the walker somehow "escapes" and never returns back to the origin. The probability of return to the origin is less than 1! For an infinite-length random walk, indeed the probability of returning to the origin $\rho$ is seen to be
#
# $$
# \rho \sim \left\{
# \begin{array}{ll}
# 1 & d=1 \\
# 1 & d=2 \\
# <1 & d\geq 3
# \end{array}
# \right.
# $$
#
# The *intuitive* explanation of this amazing fact is that, as the dimension $d$ grows, there are "more directions available", and so more chances for the walker to "get lost" and never return to the origin. There is of course a formal proof as well, but today we will do a **computational verification** of these facts, which is no substitute for a formal proof but is often all we can do!

# %% [markdown]
# ## Generating Random Walks

# %% [markdown]
# ### Exercise 3.1
# Write a function that generates a random walk of given length in $d$ dimensions. Your random walker should move as follows:
#
# + At each time-step, the walker moves only in one direction.
# + At each time-step, the walker moves only by -1 or +1
#
# Your function should return a numpy array of shape (`length`, `dim`). Example:
# ```python
# >>> # create a RW of length 10 in dimension 3
# >>> traj = get_traj(length=10, dim=3)
# >>> # check that the output has the right shape
# >>> traj.shape
# (10, 3)
# ```

# %%
def get_traj(length=100, dim=2):
    """Generate a RW in d dimensions
    
    Parameters
    ----------
    length: int
        Length of the RW.
    dim: int
        Dimension of the RW


    Returns
    -------
    traj : np.ndarray, (length, dim)
        The positions of the RW.
    
    Notes
    -----
    At each time-step, the walker moves in only one direction.
    At each time-step, the walker moves by -1 or +1
    """
    traj = np.ndarray (shape = (length, dim),dtype=int)
    for step in range (length):
    
        if step == 0:
            traj [0,:] = np.zeros(dim)
        else:
            traj[step,:] = traj[step-1,:] + new_step_RW(dim=dim)
    return traj
def new_step_RW(dim : int):
    """ Generate a new step for the RW
    
    Parameters
    ----------
    dim: int
        Dimension of the RW
    Returns
    -------
    step_RW : np.array, (dim)
        the next step of the walker 
        e.g. dim = 3,
        new_step_RW = [0,-1,0],
        it means the walker moved of -1 in dimensione 2
    
    """
                
    assert dim >0
    dim_of_step = np.random.randint(dim)
    new_step_RW = np.array([np.random.choice([1,-1]) if  x == dim_of_step else 0 for x in range(dim)])
    return new_step_RW

# %% [markdown]
# ### Verification
# To make sure that your function works correctly, execute the following cell. Notice the use of `assert` statements: execution should fail if something goes wrong. If everything is fine, nothing should happen.

# %%
# basic checks for your RW generator
for dim in range(1, 5):
    for length in [10, 100, 200, 500]:
        traj = get_traj(length=length, dim=dim)
        # make sure traj has the right shape
        assert traj.shape == (length, dim)
        # make sure all steps are -1 or 1 in only one direction
        assert np.all(np.sum(np.diff(traj, axis=0) != 0, axis=1) == np.ones(length - 1))

# %% [markdown]
# ### Exercise 3.2
# Plot a random walk of length $10^4$ for $d=1$ (time in x-axis, position in y-axis) and $d=2$ (x,y components in x,y-axis). Remember to use **axis labels**.

# %%
# it is better if you use one cell to generate the random walks, and a second cell to plot them
length = 10**4;
RW_1d = get_traj(length=length,dim=1)
RW_2d = get_traj(length=length,dim=2)

# %%
# We generate a figure with two subplots, called axis in matplotlib.
#
# To use the left subplot, we do
# ax1.plot(...)
#
# while to use the right subplot, we do
# ax2.plot(..)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))

def symmetrize_y_axis(axes):
    """symmetrize y axes in order to have 0 in the center"""
    y_max = np.abs(axes.get_ylim()).max()
    axes.set_ylim(ymin=-y_max, ymax=y_max)
def symmetrize_x_axis(axes):
    """symmetrize x axes in order to have 0 in the center"""
    x_max = np.abs(axes.get_xlim()).max()
    axes.set_xlim(xmin=-x_max, xmax=x_max)
    
    
"""plot 1d"""
ax1.plot(RW_1d,
         color = "orange",
         lw=2,
        );
#origin axis
ax1.axhline(y=0, c="black",linestyle = '-.',alpha=.3)

#symmetriza y-axis
symmetrize_y_axis(ax1)

# add title
ax1.set_title(f"1-D random Walk \n length={length}");

# add labels for axes
ax1.set_xlabel(r"Time",fontweight='bold');
ax1.set_ylabel(r"x",fontweight='bold');

# #plotting 10 elements
# ax1.plot(np.linspace(0,9000,10,dtype=int),
#          RW_1d[np.linspace(0,9000,10,dtype=int)],
#          color="r",
#          marker = 'o',
#          ms=8,
#          linestyle='',
#          label = '$\Delta Nstep = 1000$'
         
# )
# ax1.legend()



"""plot 2d"""
ax2.plot(RW_2d[:,0],RW_2d[:,1],
         color = "purple",
         lw=2
        );
#origin axis
ax2.axhline(y=0, c="black", linestyle = '-.',alpha=.3)
ax2.axvline(x=0, c="black", linestyle = '-.',alpha=.3)

#symmetriza axes
symmetrize_x_axis(ax2)
symmetrize_y_axis(ax2)

# add title
ax2.set_title(f"2-D random Walk \n length={length}");
# add labels for axes
ax2.set_xlabel(r"$x$",fontweight='bold');
ax2.set_ylabel(r"$y$",fontweight='bold');

#plotting 10 elements
# ax2.plot(RW_2d[np.linspace(0,9000,10,dtype=int),0],
#          RW_2d[np.linspace(0,9000,10,dtype=int),1],
#          color="r",
#          marker = 'o',
#          ms=8,
#          linestyle='',
#          label = '$\Delta Nstep = 1000$'
         
# );
# ax2.legend();

# %% [markdown]
# ## Counting the number of returns to the origin
# Since we are interested in how **the expected number of returns to the origin** scales with the RW length, we don't need to store the whole trajectory of each simulation (we will be performing many simulations!).

# %% [markdown]
# ### Exercise 3.3
# Write a function that generates a RW of given length and dimension (calling `get_traj`), and returns the number of times it returned to the origin. To count the number of returns to the origin, you might need to use the following functions:
# ```python
# np.all()
# np.zeros()
# ```

# %%
def get_num_returns(length, dim):
    # generate a RW of given length and dimension
    traj = get_traj(length=length,dim=dim)
    # count how many times it goes through the origin
    
    """The RW is in the origin if all the elements of a row are equal to 0.
    To get the number of returns to the origin we count the rows with all 0 value,
    hence the total number of steps - the # of the rows which are non equal to 0. This is obtained thanks to any() method
    """
    
    num_returns_to_origin = length - np.sum(traj.any(axis=1))

    #due to how the RW was created it always has the first row equal to 0, in order not to count it as a 'return' we substract it
    num_returns_to_origin -= 1
    
    return num_returns_to_origin

# %% [markdown]
# ### Exercise 3.4
# Write a function that computes the expected number of returns to the origin for a given length and dimension. Your function will call `get_num_returns()`, and should have an additional parameter that sets the sample size.

# %%
def get_average_num_returns(length, dim, num_trajs=200):
    
    average_num_returns = np.sum(np.array([
        get_num_returns(length=length,dim=dim) 
        for _ in range(num_trajs)])) /num_trajs
    return average_num_returns

# %% [markdown]
# ## Comparing with analytical results
# We are now ready to compare our analytical results with numerical simulations! We want to plot the expected number of returns to the origin as a function of the RW length. To do this, it is useful to first define an array of RW lengths.

# %%
# define range of RW lengths
length_min = 1
length_max = 100000
#length_max = 100000
# generate points logarithmically spaces
# and convert them to integers
length_array = np.array([
    int(x)
    for x in np.geomspace(length_min, length_max, num=20)
])

# %% [markdown]
# (tip: if your RW generating function is not very efficient, you might want to decrease `length_min`)
#
# Executing the following cell will run all simulations for $d=1$

# %%
# %time
dim=1
#200 trajs to average are maybe too much for my poor CPU
num_returns_array = np.array([
    get_average_num_returns(length=length, dim=dim,num_trajs=50)
    for length in length_array
])

# %% [markdown]
# ### Exercise 3.5
# Plot the average number of returns to the origin of a 1D RW as a function of the RW length, together with the expected theoretical result. Do your results verify the $n^{1/2}$ scaling? **Tip** Use double-logarithmic scales in your plot. Remember to include label axis, and a legend!

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
# plot theoretical result 
#N_returns is approximately the square root of the # of steps
ax.loglog(length_array,
          np.sqrt(length_array),
          linestyle='dashdot',
          label="Theory")

# plot numerical result
ax.loglog(length_array,
            num_returns_array,
            color="orange",
            marker = 'o',
            ms=5,
            linestyle='',
            label="Numerics")

# a axis labels
ax.set_xlabel("log($N_{step}$)")
ax.set_ylabel("log($N_{returns}$)")
# add a legend
ax.legend(loc=(0.95, 0.7), frameon=False)

# add a title (e.g. that says what dimension we used)
ax.set_title(f"Returns to the origin of a {dim}-D discrete time Random Walk");

# %% [markdown]
# ### Exercise 3.6
# Plot the average number of returns to the origin of a 2D RW as a function of the RW length. Do your results verify the $log(n)$ scaling? What are the best axis scales to use in this case?

# %%
# define range of RW lengths
length_min = 1
length_max = 1000
#length_max = 100000
# generate points logarithmically spaces
# and convert them to integers
length_array = np.array([
    int(x)
    for x in np.geomspace(length_min, length_max, num=20)
])

# %%
dim=2
#keeping track of time of execution
start = time.time()
#obtaining the averages
num_returns_array = np.array([
    get_average_num_returns(length=length, dim=dim, num_trajs=100)
    for length in length_array
])

end = time.time()
# print the difference between start
# and end time in milli. secs
print("The time of execution of above program is :",
      (end-start) , "s")
# Out:
# The time of execution of above program is : 3.2338755130767822 s

# %% [markdown]
# ## Plot 2-D RW
# The plot is linear(y axis)-log(x axis)  in order to have a better presentation of the data due to the esiguous number of returns

# %%
# plot the numerical results + theory
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
# plot theoretical result 
#N_returns is approximately the square root of the # of steps
ax.set_xscale('log')
ax.plot(length_array,
            np.log(length_array),
            linestyle='dashdot',
            label="Theory")

# plot numerical result
ax.plot(length_array,
            num_returns_array,
            color="orange",
            marker = 'o',
            ms=5,
            linestyle='',
            label="Numerics")

# add axis labels
ax.set_xlabel("($log(N_{step})$)")
ax.set_ylabel("$N_{returns}$")
# add a legend
ax.legend(loc=(0.95, 0.7), frameon=False)

# add a title (e.g. that says what dimension we used)
ax.set_title(f"Returns to the origin of a {dim}-D discrete time Random Walk");

# %% [markdown]
# ### E' evidente come la simulazione non scali esattamente come $log n$
# E'altrettanto evidente come l'andamento sia comunque lineare (n.b. logaritmico visto l'asse delle ascisse),
# mediante una regressione è possibile ottenere tale inclinazione.

# %% [markdown]
# # TO DO: REGRESSIONE

# %% [markdown]
# ### Exercise 3.7
# Show numerically that, for $d=3$ and $d=4$, the expected number of returns to the origin is **constant**.

# %%
# your numerical answer here
# you can use more than one cell of course!
# use markdown cells and code cells if necessary

# %%
# define range of RW lengths
length_min = 1
length_max = 10000
#length_max = 100000
# generate points logarithmically spaces
# and convert them to integers
length_array = np.array([
    int(x)
    for x in np.geomspace(length_min, length_max, num=20)
])

# %% [markdown]
# # 3D

# %%
# %%time
dim=3
#200 trajs to average are maybe too much for my poor CPU
num_returns_array_3D = np.array([
    get_average_num_returns(length=length, dim=dim,num_trajs=50)
    for length in length_array
])
# Out:
# CPU times: user 12 s, sys: 60 ms, total: 12.1 s
# Wall time: 12 s

# %% [markdown]
# # 4D

# %%
start = time.time()

# %%
dim=4
#200 trajs to average are maybe too much for my poor CPU
num_returns_array_4D = np.array([
    get_average_num_returns(length=length, dim=dim,num_trajs=50)
    for length in length_array
])

# %%
end = time.time()
# print the difference between start
# and end time in milli. secs
print("The time of execution of above program is :",
      (end-start), "s /n",
     (end-start)/60,"min")
# Out:
# The time of execution of above program is : 1.6207730770111084 s /n 0.027012884616851807 min

# %%
start = time.time()

# %%
dim=4
#200 trajs to average are maybe too much for my poor CPU
num_returns_array_4D = np.array([
    get_average_num_returns(length=length, dim=dim,num_trajs=50)
    for length in length_array
])

# %%
end = time.time()
# print the difference between start
# and end time in milli. secs
print("The time of execution of above program is :",
      (end-start), "s /n",
     (end-start)/60,"min")
# Out:
# The time of execution of above program is : 1.5897681713104248 s /n 0.02649613618850708 min

# %% [markdown]
# ## Plot 3/4-D RW
# The plot is linear(y axis)-log(x axis)  in order to have a better presentation of the data due to the esiguous number of returns

# %%
# plot the numerical results + theory
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
# plot theoretical result 
#N_returns is approximately the square root of the # of steps
ax.set_xscale('log')
ax.plot(length_array,
            num_returns_array_3D,
            color="orange",
            marker = 'o',
            ms=5,
            linestyle='-',
            label="3D")

# plot numerical result
ax.plot(length_array,
            num_returns_array_4D,
            color="red",
            marker = 'X',
            ms=5,
            linestyle='-',
            label="4D")

ax.set_ylim([0,3])
# add axis labels
ax.set_xlabel("($log(N_{step})$)")
ax.set_ylabel("$(N_{returns})$")
# add a legend
ax.legend(loc=(0.95, 0.7), frameon=False)

# add a title (e.g. that says what dimension we used)
ax.set_title(f"Returns to the origin of a {dim}-D discrete time Random Walk");

# %% [markdown]
# # Self-Avoiding Walks
# Self-avoiding walks (SAW) are simply random walks in a regular lattice with the additional constraint that no point can be visited more than once. That is, SAWs cannot intersect themselves. The most well-known application of SAW is to model linear polymers, where obviously two monomers cannot occupy the same space (excluded volume effect).
#
#
# You can read more about self-avoiding walks in this nice introduction by Gordon Slade:
#
# [Self-Avoiding Walks, by Gordon Slade](https://www.math.ubc.ca/~slade/intelligencer.pdf)

# %% [markdown]
# ## Simulating Self-Avoiding Walks
# Generating a SAW is not trivial. If you try to generate a SAW stochastically, that is, one step at a time, you will miserably fail: your walker might get into traps (configurations with no allowed movements), and if it does you will have to discard your simulation. It turns out you will have to discard your simulation *really* often, so that for large lengths, you will basically never find a valid path. In addition, the paths you will find for short lengths will not come up with the right probabilities. Bear in mind that we want to **uniformly sample** the set of SAW of given length $n$, SAW($n$). That is, we want that all paths from SAW($n$) are generated with the same probability.
#
# The solution is to use a Monte Carlo algorithm that, given one element $\alpha \in \text{SAW}(n)$, generates a new one $\beta \in \text{SAW}(n)$ with some probability $P_{\alpha \beta}$. If in addition our algorithm satisfies **detailed balance** and is **ergodic**, then we known that it will converge to the equilibrium distribution (the uniform distribution in our case).

# %% [markdown]
# ## The pivot algorithm
# We will implement the pivot algorithm, which is simple, effective, and satisfies detailed balance and ergodicity. You can read about the details of the pivot algorithm here:
#
# [The Pivot Algorithm: A Highly Efficient Monte Carlo Method for the Self-Avoiding Walk](https://link.springer.com/article/10.1007/BF01022990)
#
# (tip: if you're at home, **do not** use tools such as sci-hub to download the paper).
#
# Given a self-avoiding walk of length $n$, the pivot algorithm generates the next walk $\beta \in \text{SAW}(n)$ as follows:
#
# 1. **Choose a point of $\alpha$ at random**, splitting the path in two bits: the head (from the origin to the chosen point) and the tail (from the chosen point to the end of the path). Notice that both the head and the tail are SAWs.
# 2. **Apply a transformation to the tail**, leaving the head intact. The transformation must be an orthoganl transformation that leaves the regular lattice intact (so, either a reflection or a $90º, 180º$ or $270º$ rotation). For simplicity, we will use only **rotations** (read the paper to see why this is ok).
# 3. **Check if the new path is self-avoiding**. If so, return it. Otherwise, return the original path.
#
# Iterating these steps one obtains a **Markov** chain of SAWs: $\alpha_1 \to \alpha_2 \to \dots \to \alpha_M $. Notice that $\alpha_i$ are not uncorrelated, but because the algorithm satisfies detailed balance and is ergodic, we know that it approaches the equilibrium distribution. This means that we can use our Markov chain to compute **expected values** as long as it is long enough.

# %% [markdown]
# ## Implementing the pivot step in 2D
# To implement the **pivot algorithm** in 2D, we will write one function that does steps 1 and 2, and another function that does step 3. We will also need a function to generate standard 2D random walks.

# %% [markdown]
# ### Exercise 3.8
# Write a function `get_traj` that generates a 2D random walk of given length.

# %%
#actually I have already done it at the beginning, I'm gonna use that one (it has dim=2 as a basic assignation)
def get_traj_2d(length):
    """Generate a 2D random walk of given length"""
    
    def new_step_RW(dim : int):
        """ Generate a new step for the RW

        Parameters
        ----------
        dim: int
            Dimension of the RW
        Returns
        -------
        step_RW : np.array, (dim)
            the next step of the walker 
            e.g. dim = 3,
            new_step_RW = [0,-1,0],
            it means the walker moved of -1 in dimensione 2

        """

        assert dim >0
        dim_of_step = np.random.randint(dim)
        new_step_RW = np.array([np.random.choice([1,-1]) if  x == dim_of_step else 0 for x in range(dim)])
        return new_step_RW
    
    dim = 2 
    traj = np.ndarray (shape = (length, dim),dtype=int)
    for step in range (length):
    
        if step == 0:
            traj [0,:] = np.zeros(dim)
        else:
            traj[step,:] = traj[step-1,:] + new_step_RW(dim=dim)
    return traj

# %% [markdown]
# ### Exercise 3.9
# Write a function `pivot_traj` that, given a 2D random walk, performs steps 1 and 2 of the pivot algorithm. Some useful functions:
# ```python
# np.random.randint()
# np.concatenate()
# ```
# You might also want to multiply matrices using the `@` operator:
# ```python
# >>> a = np.array([[1, 2], [3, 4], [5, 6]])
# >>> b = np.array([1, 1])
# >>> a @ b
# array([ 3,  7, 11])
# ```

# %%
def pivot_traj(traj):
    """Apply a random rotation to part of a RW."""
    
    # choose the pivot
    #choosing any step of the random walk
    pivot_index = np.random.randint(low=0,high=np.size(traj,axis=0))
    
    #adding here the selection of both columns
    pivot_point = traj[pivot_index,:]

    # split head and tail
    traj_head = traj[:pivot_index,:]
    traj_tail = traj[pivot_index:,:]
    
    # define the rotation matrices
    #generic rotation matrix = ([[cos th ,-sen th ], [sen th , cos th]]),
    symmetries = [
        # 90 deg rotation
        np.array([[0 ,-1 ], [1 ,0 ]]),
        # 180 deg rotation
        np.array([[-1 ,0 ], [0 ,-1 ]]),
        # 270 deg rotation
        np.array([[0 ,1 ], [-1 ,0 ]]),
    ]
    
    # choose one rotation at random
    symmetry = symmetries[np.random.randint(low=0,high=3)]
    #print(symmetry)
    # apply the transformation to the tail
    #I first center it and then rotate it
    new_tail = ((traj_tail - pivot_point) @ symmetry) + pivot_point
    
    # join the old head with the new tail
    new_traj = np.concatenate((traj_head,new_tail))
    
    return new_traj

# %% [markdown]
# ### Exercise 3.10
# Write a function that counts the number of self-intersections of a RW. Notice that SAWs have 0 self intersections, so that will solve step 3 of the pivot algorithm, but will also be useful to generate the initial condition. One way of approaching this exercise is to count how many *different* points the path visits.

# %%
def count_self_intersections(traj):
    """Count the number of self-intersections of a RW"""
    #different points path visited
    n_points_visited = np.size(np.unique(traj,axis=0),axis=0)
    #number of steps of the RW
    n_steps_traj = np.size(traj,axis=0)
    # the # of self intersection is simply given by: N_made - N_visited
    num_self_intersections = n_steps_traj - n_points_visited
    return num_self_intersections

# %%
#Thanks to Emilio Annoni for the advice of using set()
def count_self_intersections(traj):
    """Count the number of self-intersections of a RW"""
    point_set = set()

    n_steps_traj = traj.shape[0]

    for i in range(n_steps_traj):
        point_set.add(tuple(traj[i,:]))

    #number of steps of the RW
    n_points_visited = len(point_set)
    # the # of self intersection is simply given by: N_made - N_visited
    num_self_intersections = n_steps_traj - n_points_visited
    return num_self_intersections

# %% [markdown]
# ### Exercise 3.11
# Verify that your `count_self_intersecitons` function works properly by using short trajectories for which you know the answer.

# %%
# your verifications here
#testing it against small RW that i can control by just looking at them... Not sure it's the best
#maybe by plotting them I can test it better, but I am too curious to see how everything works together
for _ in range(6):
    traj = get_traj (length = 4)
    n_intersection = count_self_intersections(traj)
    print("la traiettorie è \n", traj, "\n Il numero delle intersezioni calcolato è: ",n_intersection)
# Out:
# la traiettorie è
#  [[ 0  0]
#  [ 0 -1]
#  [-1 -1]
#  [-1  0]]
#  Il numero delle intersezioni calcolato è:  0
# la traiettorie è
#  [[ 0  0]
#  [-1  0]
#  [ 0  0]
#  [ 0  1]]
#  Il numero delle intersezioni calcolato è:  1
# la traiettorie è
#  [[ 0  0]
#  [-1  0]
#  [ 0  0]
#  [ 1  0]]
#  Il numero delle intersezioni calcolato è:  1
# la traiettorie è
#  [[ 0  0]
#  [-1  0]
#  [ 0  0]
#  [ 0 -1]]
#  Il numero delle intersezioni calcolato è:  1
# la traiettorie è
#  [[ 0  0]
#  [ 0 -1]
#  [ 0  0]
#  [ 0  1]]
#  Il numero delle intersezioni calcolato è:  1
# la traiettorie è
#  [[ 0  0]
#  [ 0  1]
#  [ 0  0]
#  [ 0 -1]]
#  Il numero delle intersezioni calcolato è:  1

# %% [markdown]
# ## sembra lavorare in modo dignitoso

# %% [markdown]
# ## Generating the initial condition
# You might have noticed that the pivot algorithm requires an element of SAW($n$) as starting condition, to then generate a Markov chain easily. But how do you get this first element? We will use the following strategy:
# 1. Generate a standard 2D random walk, and count the number of self intersections.
# 2. Apply the pivot transformation to get a new 2D random walk, and count the number of self-intersections-
# 3. If the number of self-intersections has decreased or not changed, keep the new path. Else, keep the old one.
# 4. Go to 2, till the number of self-intersections is 0.
#
# ### Exercise 3.12
# Write a function `get_first_SAW` that generates a SAW of given length

# %%
#probably it is faster like this but this function needs recursion...
def get_first_SAW(length, max_tries=1000000,debug = False):
    traj = get_traj(length)
    n_intersection = count_self_intersections(traj)
    n_intersection_ref = n_intersection
#     print(traj)
    n_tries = 0;
    while n_intersection > 0:
        n_tries +=1
        new_traj = pivot_traj(traj)
        n_intersection = count_self_intersections(new_traj)
#         if np.mod(ii,100) ==0:
#             print ('intersection number: \t',n_intersection, '\n and traj is \n', new_traj)
#         if new intersection number has improved we change path and change our reference # with the new one
        if n_intersection <= n_intersection_ref:
            if debug and n_intersection < n_intersection_ref:
                print(n_intersection,'\t left to unravel')
            n_intersection_ref = n_intersection
            traj = new_traj
            
        #se arriviamo al massimo dei tentativi riproviamo con un nuovo SAW    
        if n_tries == max_tries:
            print('Sorry, Too many tries, i am gonna start all over again ')
            return get_first_SAW(length)
            
    #print ('HA RICHIESTO SOLO:\t', ii, 'ITERAZIONI')
    return traj

# %% [markdown]
# ### Exercise 3.13
# Generate and plot some 2D SAWs of different lengths. Be carefull, raise the length slowly! You can measure how long a cell takes executing using the `%%time` magic at the top of a cell.

# %%
# your answer here
# use more than one cell!

# %% [markdown]
# ## Benchmarking the dimension of a feasible SAW_RW

# %%
# %%time
# define thelength
length = 10000

start = time.time()

SAW_RW = get_first_SAW(length,debug=True)

end = time.time()
# print the difference between start
# and end time in milli. secs
print("The time of execution of above program is :",
      (end-start), "s /n",
     (end-start)/60,"min")

"""plot 2d"""
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

ax.plot(SAW_RW[:,0],SAW_RW[:,1],
         color = "purple",
         lw=2
        );
#origin axis
ax.axhline(y=0, c="black", linestyle = '-.',alpha=.3)
ax.axvline(x=0, c="black", linestyle = '-.',alpha=.3)

#symmetriza axes
symmetrize_x_axis(ax)
symmetrize_y_axis(ax)

# add title
ax.set_title(f"2-D SELF AVOIDING random Walk \n length={length}");
# add labels for axes
ax.set_xlabel(r"$x$",fontweight='bold');
ax.set_ylabel(r"$y$",fontweight='bold');
# Out:
# 6977 	 left to unravel
# 6912 	 left to unravel
# 6871 	 left to unravel
# 6869 	 left to unravel
# 6864 	 left to unravel
# 6834 	 left to unravel
# 6832 	 left to unravel
# 6785 	 left to unravel
# 6762 	 left to unravel
# 6657 	 left to unravel
# 6642 	 left to unravel
# 6621 	 left to unravel
# 6557 	 left to unravel
# 6556 	 left to unravel
# 6545 	 left to unravel
# 6535 	 left to unravel
# 6475 	 left to unravel
# 6468 	 left to unravel
# 6440 	 left to unravel
# 6427 	 left to unravel
# 6424 	 left to unravel
# 6414 	 left to unravel
# 6360 	 left to unravel
# 6356 	 left to unravel
# 6328 	 left to unravel
# 6302 	 left to unravel
# 6292 	 left to unravel
# 6271 	 left to unravel
# 6267 	 left to unravel
# 6256 	 left to unravel
# 6248 	 left to unravel
# 6226 	 left to unravel
# 6208 	 left to unravel
# 6204 	 left to unravel
# 6201 	 left to unravel
# 6188 	 left to unravel
# 6181 	 left to unravel
# 6171 	 left to unravel
# 6169 	 left to unravel
# 6158 	 left to unravel
# 6157 	 left to unravel
# 6155 	 left to unravel
# 6154 	 left to unravel
# 6152 	 left to unravel
# 6136 	 left to unravel
# 6135 	 left to unravel
# 6134 	 left to unravel
# 6131 	 left to unravel
# 6127 	 left to unravel
# 6119 	 left to unravel
# 6112 	 left to unravel
# 6110 	 left to unravel
# 6100 	 left to unravel
# 6095 	 left to unravel
# 6090 	 left to unravel
# 6088 	 left to unravel
# 6074 	 left to unravel
# 6073 	 left to unravel
# 6050 	 left to unravel
# 6049 	 left to unravel
# 6035 	 left to unravel
# 6028 	 left to unravel
# 6027 	 left to unravel
# 6026 	 left to unravel
# 6019 	 left to unravel
# 6014 	 left to unravel
# 6004 	 left to unravel
# 5995 	 left to unravel
# 5980 	 left to unravel
# 5978 	 left to unravel
# 5963 	 left to unravel
# 5961 	 left to unravel
# 5959 	 left to unravel
# 5958 	 left to unravel
# 5952 	 left to unravel
# 5950 	 left to unravel
# 5946 	 left to unravel
# 5932 	 left to unravel
# 5909 	 left to unravel
# 5905 	 left to unravel
# 5899 	 left to unravel
# 5888 	 left to unravel
# 5887 	 left to unravel
# 5886 	 left to unravel
# 5881 	 left to unravel
# 5872 	 left to unravel
# 5866 	 left to unravel
# 5865 	 left to unravel
# 5861 	 left to unravel
# 5859 	 left to unravel
# 5858 	 left to unravel
# 5856 	 left to unravel
# 5831 	 left to unravel
# 5814 	 left to unravel
# 5813 	 left to unravel
# 5812 	 left to unravel
# 5811 	 left to unravel
# 5810 	 left to unravel
# 5808 	 left to unravel
# 5806 	 left to unravel
# 5801 	 left to unravel
# 5795 	 left to unravel
# 5791 	 left to unravel
# 5783 	 left to unravel
# 5780 	 left to unravel
# 5764 	 left to unravel
# 5763 	 left to unravel
# 5761 	 left to unravel
# 5757 	 left to unravel
# 5755 	 left to unravel
# 5751 	 left to unravel
# 5750 	 left to unravel
# 5747 	 left to unravel
# 5746 	 left to unravel
# 5734 	 left to unravel
# 5733 	 left to unravel
# 5732 	 left to unravel
# 5729 	 left to unravel
# 5727 	 left to unravel
# 5726 	 left to unravel
# 5725 	 left to unravel
# 5719 	 left to unravel
# 5714 	 left to unravel
# 5711 	 left to unravel
# 5705 	 left to unravel
# 5702 	 left to unravel
# 5685 	 left to unravel
# 5684 	 left to unravel
# 5682 	 left to unravel
# 5678 	 left to unravel
# 5677 	 left to unravel
# 5676 	 left to unravel
# 5659 	 left to unravel
# 5658 	 left to unravel
# 5651 	 left to unravel
# 5646 	 left to unravel
# 5642 	 left to unravel
# 5638 	 left to unravel
# 5637 	 left to unravel
# 5632 	 left to unravel
# 5616 	 left to unravel
# 5612 	 left to unravel
# 5607 	 left to unravel
# 5601 	 left to unravel
# 5594 	 left to unravel
# 5585 	 left to unravel
# 5582 	 left to unravel
# 5578 	 left to unravel
# 5576 	 left to unravel
# 5571 	 left to unravel
# 5569 	 left to unravel
# 5566 	 left to unravel
# 5559 	 left to unravel
# 5558 	 left to unravel
# 5556 	 left to unravel
# 5554 	 left to unravel
# 5550 	 left to unravel
# 5549 	 left to unravel
# 5545 	 left to unravel
# 5544 	 left to unravel
# 5543 	 left to unravel
# 5541 	 left to unravel
# 5539 	 left to unravel
# 5537 	 left to unravel
# 5530 	 left to unravel
# 5528 	 left to unravel
# 5519 	 left to unravel
# 5518 	 left to unravel
# 5516 	 left to unravel
# 5510 	 left to unravel
# 5504 	 left to unravel
# 5503 	 left to unravel
# 5497 	 left to unravel
# 5496 	 left to unravel
# 5495 	 left to unravel
# 5482 	 left to unravel
# 5480 	 left to unravel
# 5467 	 left to unravel
# 5465 	 left to unravel
# 5447 	 left to unravel
# 5437 	 left to unravel
# 5436 	 left to unravel
# 5434 	 left to unravel
# 5429 	 left to unravel
# 5427 	 left to unravel
# 5420 	 left to unravel
# 5416 	 left to unravel
# 5415 	 left to unravel
# 5414 	 left to unravel
# 5404 	 left to unravel
# 5403 	 left to unravel
# 5402 	 left to unravel
# 5399 	 left to unravel
# 5396 	 left to unravel
# 5391 	 left to unravel
# 5388 	 left to unravel
# 5386 	 left to unravel
# 5385 	 left to unravel
# 5383 	 left to unravel
# 5374 	 left to unravel
# 5370 	 left to unravel
# 5366 	 left to unravel
# 5365 	 left to unravel
# 5364 	 left to unravel
# 5362 	 left to unravel
# 5360 	 left to unravel
# 5358 	 left to unravel
# 5351 	 left to unravel
# 5347 	 left to unravel
# 5346 	 left to unravel
# 5338 	 left to unravel
# 5337 	 left to unravel
# 5336 	 left to unravel
# 5331 	 left to unravel
# 5330 	 left to unravel
# 5327 	 left to unravel
# 5322 	 left to unravel
# 5320 	 left to unravel
# 5313 	 left to unravel
# 5312 	 left to unravel
# 5311 	 left to unravel
# 5305 	 left to unravel
# 5303 	 left to unravel
# 5294 	 left to unravel
# 5292 	 left to unravel
# 5289 	 left to unravel
# 5286 	 left to unravel
# 5283 	 left to unravel
# 5282 	 left to unravel
# 5275 	 left to unravel
# 5272 	 left to unravel
# 5271 	 left to unravel
# 5265 	 left to unravel
# 5264 	 left to unravel
# 5262 	 left to unravel
# 5261 	 left to unravel
# 5247 	 left to unravel
# 5242 	 left to unravel
# 5240 	 left to unravel
# 5234 	 left to unravel
# 5230 	 left to unravel
# 5226 	 left to unravel
# 5225 	 left to unravel
# 5221 	 left to unravel
# 5216 	 left to unravel
# 5211 	 left to unravel
# 5208 	 left to unravel
# 5206 	 left to unravel
# 5205 	 left to unravel
# 5201 	 left to unravel
# 5200 	 left to unravel
# 5196 	 left to unravel
# 5195 	 left to unravel
# 5188 	 left to unravel
# 5187 	 left to unravel
# 5184 	 left to unravel
# 5183 	 left to unravel
# 5182 	 left to unravel
# 5176 	 left to unravel
# 5175 	 left to unravel
# 5173 	 left to unravel
# 5170 	 left to unravel
# 5160 	 left to unravel
# 5159 	 left to unravel
# 5156 	 left to unravel
# 5153 	 left to unravel
# 5151 	 left to unravel
# 5148 	 left to unravel
# 5144 	 left to unravel
# 5142 	 left to unravel
# 5136 	 left to unravel
# 5134 	 left to unravel
# 5127 	 left to unravel
# 5125 	 left to unravel
# 5124 	 left to unravel
# 5121 	 left to unravel
# 5109 	 left to unravel
# 5102 	 left to unravel
# 5101 	 left to unravel
# 5097 	 left to unravel
# 5096 	 left to unravel
# 5094 	 left to unravel
# 5091 	 left to unravel
# 5090 	 left to unravel
# 5086 	 left to unravel
# 5085 	 left to unravel
# 5081 	 left to unravel
# 5077 	 left to unravel
# 5065 	 left to unravel
# 5056 	 left to unravel
# 5047 	 left to unravel
# 5045 	 left to unravel
# 5044 	 left to unravel
# 5041 	 left to unravel
# 5038 	 left to unravel
# 5036 	 left to unravel
# 5035 	 left to unravel
# 5034 	 left to unravel
# 5030 	 left to unravel
# 5028 	 left to unravel
# 5027 	 left to unravel
# 5023 	 left to unravel
# 5021 	 left to unravel
# 5017 	 left to unravel
# 5015 	 left to unravel
# 5013 	 left to unravel
# 5004 	 left to unravel
# 5003 	 left to unravel
# 5001 	 left to unravel
# 4998 	 left to unravel
# 4997 	 left to unravel
# 4995 	 left to unravel
# 4993 	 left to unravel
# 4992 	 left to unravel
# 4987 	 left to unravel
# 4979 	 left to unravel
# 4977 	 left to unravel
# 4974 	 left to unravel
# 4968 	 left to unravel
# 4966 	 left to unravel
# 4965 	 left to unravel
# 4964 	 left to unravel
# 4960 	 left to unravel
# 4959 	 left to unravel
# 4955 	 left to unravel
# 4954 	 left to unravel
# 4948 	 left to unravel
# 4945 	 left to unravel
# 4943 	 left to unravel
# 4940 	 left to unravel
# 4939 	 left to unravel
# 4932 	 left to unravel
# 4926 	 left to unravel
# 4923 	 left to unravel
# 4920 	 left to unravel
# 4919 	 left to unravel
# 4916 	 left to unravel
# 4915 	 left to unravel
# 4913 	 left to unravel
# 4910 	 left to unravel
# 4904 	 left to unravel
# 4901 	 left to unravel
# 4897 	 left to unravel
# 4895 	 left to unravel
# 4894 	 left to unravel
# 4891 	 left to unravel
# 4889 	 left to unravel
# 4888 	 left to unravel
# 4885 	 left to unravel
# 4881 	 left to unravel
# 4880 	 left to unravel
# 4878 	 left to unravel
# 4873 	 left to unravel
# 4870 	 left to unravel
# 4869 	 left to unravel
# 4868 	 left to unravel
# 4863 	 left to unravel
# 4859 	 left to unravel
# 4857 	 left to unravel
# 4849 	 left to unravel
# 4848 	 left to unravel
# 4844 	 left to unravel
# 4836 	 left to unravel
# 4833 	 left to unravel
# 4832 	 left to unravel
# 4831 	 left to unravel
# 4830 	 left to unravel
# 4824 	 left to unravel
# 4820 	 left to unravel
# 4818 	 left to unravel
# 4813 	 left to unravel
# 4812 	 left to unravel
# 4808 	 left to unravel
# 4807 	 left to unravel
# 4805 	 left to unravel
# 4803 	 left to unravel
# 4802 	 left to unravel
# 4801 	 left to unravel
# 4797 	 left to unravel
# 4796 	 left to unravel
# 4790 	 left to unravel
# 4786 	 left to unravel
# 4785 	 left to unravel
# 4782 	 left to unravel
# 4781 	 left to unravel
# 4779 	 left to unravel
# 4774 	 left to unravel
# 4769 	 left to unravel
# 4766 	 left to unravel
# 4762 	 left to unravel
# 4761 	 left to unravel
# 4753 	 left to unravel
# 4750 	 left to unravel
# 4745 	 left to unravel
# 4742 	 left to unravel
# 4739 	 left to unravel
# 4736 	 left to unravel
# 4733 	 left to unravel
# 4732 	 left to unravel
# 4731 	 left to unravel
# 4728 	 left to unravel
# 4727 	 left to unravel
# 4726 	 left to unravel
# 4721 	 left to unravel
# 4720 	 left to unravel
# 4717 	 left to unravel
# 4716 	 left to unravel
# 4715 	 left to unravel
# 4710 	 left to unravel
# 4709 	 left to unravel
# 4708 	 left to unravel
# 4707 	 left to unravel
# 4706 	 left to unravel
# 4705 	 left to unravel
# 4704 	 left to unravel
# 4702 	 left to unravel
# 4699 	 left to unravel
# 4694 	 left to unravel
# 4691 	 left to unravel
# 4688 	 left to unravel
# 4687 	 left to unravel
# 4685 	 left to unravel
# 4684 	 left to unravel
# 4682 	 left to unravel
# 4681 	 left to unravel
# 4679 	 left to unravel
# 4678 	 left to unravel
# 4676 	 left to unravel
# 4672 	 left to unravel
# 4670 	 left to unravel
# 4666 	 left to unravel
# 4665 	 left to unravel
# 4663 	 left to unravel
# 4662 	 left to unravel
# 4660 	 left to unravel
# 4659 	 left to unravel
# 4658 	 left to unravel
# 4657 	 left to unravel
# 4653 	 left to unravel
# 4651 	 left to unravel
# 4648 	 left to unravel
# 4647 	 left to unravel
# 4645 	 left to unravel
# 4644 	 left to unravel
# 4642 	 left to unravel
# 4640 	 left to unravel
# 4639 	 left to unravel
# 4637 	 left to unravel
# 4635 	 left to unravel
# 4634 	 left to unravel
# 4632 	 left to unravel
# 4628 	 left to unravel
# 4627 	 left to unravel
# 4626 	 left to unravel
# 4625 	 left to unravel
# 4620 	 left to unravel
# 4619 	 left to unravel
# 4618 	 left to unravel
# 4617 	 left to unravel
# 4616 	 left to unravel
# 4615 	 left to unravel
# 4612 	 left to unravel
# 4611 	 left to unravel
# 4610 	 left to unravel
# 4605 	 left to unravel
# 4602 	 left to unravel
# 4601 	 left to unravel
# 4600 	 left to unravel
# 4593 	 left to unravel
# 4592 	 left to unravel
# 4591 	 left to unravel
# 4590 	 left to unravel
# 4588 	 left to unravel
# 4583 	 left to unravel
# 4580 	 left to unravel
# 4578 	 left to unravel
# 4572 	 left to unravel
# 4570 	 left to unravel
# 4566 	 left to unravel
# 4564 	 left to unravel
# 4562 	 left to unravel
# 4556 	 left to unravel
# 4555 	 left to unravel
# 4552 	 left to unravel
# 4550 	 left to unravel
# 4547 	 left to unravel
# 4545 	 left to unravel
# 4543 	 left to unravel
# 4541 	 left to unravel
# 4540 	 left to unravel
# 4538 	 left to unravel
# 4537 	 left to unravel
# 4528 	 left to unravel
# 4527 	 left to unravel
# 4520 	 left to unravel
# 4519 	 left to unravel
# 4517 	 left to unravel
# 4516 	 left to unravel
# 4514 	 left to unravel
# 4513 	 left to unravel
# 4512 	 left to unravel
# 4511 	 left to unravel
# 4509 	 left to unravel
# 4508 	 left to unravel
# 4505 	 left to unravel
# 4503 	 left to unravel
# 4502 	 left to unravel
# 4500 	 left to unravel
# 4495 	 left to unravel
# 4494 	 left to unravel
# 4493 	 left to unravel
# 4486 	 left to unravel
# 4480 	 left to unravel
# 4478 	 left to unravel
# 4471 	 left to unravel
# 4470 	 left to unravel
# 4463 	 left to unravel
# 4462 	 left to unravel
# 4458 	 left to unravel
# 4457 	 left to unravel
# 4456 	 left to unravel
# 4455 	 left to unravel
# 4454 	 left to unravel
# 4451 	 left to unravel
# 4450 	 left to unravel
# 4448 	 left to unravel
# 4445 	 left to unravel
# 4444 	 left to unravel
# 4441 	 left to unravel
# 4440 	 left to unravel
# 4439 	 left to unravel
# 4436 	 left to unravel
# 4435 	 left to unravel
# 4433 	 left to unravel
# 4429 	 left to unravel
# 4428 	 left to unravel
# 4427 	 left to unravel
# 4426 	 left to unravel
# 4425 	 left to unravel
# 4424 	 left to unravel
# 4423 	 left to unravel
# 4421 	 left to unravel
# 4420 	 left to unravel
# 4418 	 left to unravel
# 4417 	 left to unravel
# 4414 	 left to unravel
# 4411 	 left to unravel
# 4407 	 left to unravel
# 4406 	 left to unravel
# 4405 	 left to unravel
# 4404 	 left to unravel
# 4403 	 left to unravel
# 4402 	 left to unravel
# 4401 	 left to unravel
# 4399 	 left to unravel
# 4398 	 left to unravel
# 4397 	 left to unravel
# 4396 	 left to unravel
# 4392 	 left to unravel
# 4391 	 left to unravel
# 4389 	 left to unravel
# 4385 	 left to unravel
# 4382 	 left to unravel
# 4381 	 left to unravel
# 4378 	 left to unravel
# 4377 	 left to unravel
# 4375 	 left to unravel
# 4373 	 left to unravel
# 4371 	 left to unravel
# 4369 	 left to unravel
# 4368 	 left to unravel
# 4363 	 left to unravel
# 4362 	 left to unravel
# 4360 	 left to unravel
# 4359 	 left to unravel
# 4358 	 left to unravel
# 4357 	 left to unravel
# 4355 	 left to unravel
# 4354 	 left to unravel
# 4352 	 left to unravel
# 4348 	 left to unravel
# 4346 	 left to unravel
# 4344 	 left to unravel
# 4343 	 left to unravel
# 4342 	 left to unravel
# 4340 	 left to unravel
# 4338 	 left to unravel
# 4337 	 left to unravel
# 4332 	 left to unravel
# 4327 	 left to unravel
# 4322 	 left to unravel
# 4321 	 left to unravel
# 4320 	 left to unravel
# 4318 	 left to unravel
# 4314 	 left to unravel
# 4312 	 left to unravel
# 4311 	 left to unravel
# 4304 	 left to unravel
# 4302 	 left to unravel
# 4299 	 left to unravel
# 4298 	 left to unravel
# 4296 	 left to unravel
# 4295 	 left to unravel
# 4291 	 left to unravel
# 4288 	 left to unravel
# 4285 	 left to unravel
# 4284 	 left to unravel
# 4283 	 left to unravel
# 4282 	 left to unravel
# 4281 	 left to unravel
# 4277 	 left to unravel
# 4270 	 left to unravel
# 4266 	 left to unravel
# 4265 	 left to unravel
# 4264 	 left to unravel
# 4260 	 left to unravel
# 4259 	 left to unravel
# 4258 	 left to unravel
# 4254 	 left to unravel
# 4253 	 left to unravel
# 4249 	 left to unravel
# 4248 	 left to unravel
# 4247 	 left to unravel
# 4243 	 left to unravel
# 4240 	 left to unravel
# 4238 	 left to unravel
# 4234 	 left to unravel
# 4228 	 left to unravel
# 4226 	 left to unravel
# 4225 	 left to unravel
# 4224 	 left to unravel
# 4222 	 left to unravel
# 4221 	 left to unravel
# 4219 	 left to unravel
# 4218 	 left to unravel
# 4216 	 left to unravel
# 4214 	 left to unravel
# 4213 	 left to unravel
# 4210 	 left to unravel
# 4209 	 left to unravel
# 4208 	 left to unravel
# 4206 	 left to unravel
# 4205 	 left to unravel
# 4202 	 left to unravel
# 4199 	 left to unravel
# 4195 	 left to unravel
# 4193 	 left to unravel
# 4190 	 left to unravel
# 4188 	 left to unravel
# 4183 	 left to unravel
# 4181 	 left to unravel
# 4180 	 left to unravel
# 4177 	 left to unravel
# 4176 	 left to unravel
# 4174 	 left to unravel
# 4173 	 left to unravel
# 4168 	 left to unravel
# 4166 	 left to unravel
# 4165 	 left to unravel
# 4164 	 left to unravel
# 4163 	 left to unravel
# 4162 	 left to unravel
# 4161 	 left to unravel
# 4159 	 left to unravel
# 4156 	 left to unravel
# 4154 	 left to unravel
# 4153 	 left to unravel
# 4150 	 left to unravel
# 4148 	 left to unravel
# 4146 	 left to unravel
# 4145 	 left to unravel
# 4143 	 left to unravel
# 4142 	 left to unravel
# 4137 	 left to unravel
# 4136 	 left to unravel
# 4134 	 left to unravel
# 4132 	 left to unravel
# 4129 	 left to unravel
# 4128 	 left to unravel
# 4125 	 left to unravel
# 4123 	 left to unravel
# 4121 	 left to unravel
# 4119 	 left to unravel
# 4118 	 left to unravel
# 4113 	 left to unravel
# 4111 	 left to unravel
# 4110 	 left to unravel
# 4108 	 left to unravel
# 4106 	 left to unravel
# 4102 	 left to unravel
# 4100 	 left to unravel
# 4098 	 left to unravel
# 4097 	 left to unravel
# 4095 	 left to unravel
# 4094 	 left to unravel
# 4092 	 left to unravel
# 4090 	 left to unravel
# 4089 	 left to unravel
# 4083 	 left to unravel
# 4082 	 left to unravel
# 4081 	 left to unravel
# 4080 	 left to unravel
# 4079 	 left to unravel
# 4078 	 left to unravel
# 4077 	 left to unravel
# 4073 	 left to unravel
# 4072 	 left to unravel
# 4070 	 left to unravel
# 4069 	 left to unravel
# 4068 	 left to unravel
# 4066 	 left to unravel
# 4063 	 left to unravel
# 4061 	 left to unravel
# 4059 	 left to unravel
# 4056 	 left to unravel
# 4054 	 left to unravel
# 4052 	 left to unravel
# 4051 	 left to unravel
# 4049 	 left to unravel
# 4047 	 left to unravel
# 4043 	 left to unravel
# 4037 	 left to unravel
# 4035 	 left to unravel
# 4034 	 left to unravel
# 4030 	 left to unravel
# 4029 	 left to unravel
# 4027 	 left to unravel
# 4025 	 left to unravel
# 4022 	 left to unravel
# 4021 	 left to unravel
# 4018 	 left to unravel
# 4017 	 left to unravel
# 4016 	 left to unravel
# 4015 	 left to unravel
# 4010 	 left to unravel
# 4008 	 left to unravel
# 4005 	 left to unravel
# 4004 	 left to unravel
# 4001 	 left to unravel
# 3998 	 left to unravel
# 3997 	 left to unravel
# 3995 	 left to unravel
# 3994 	 left to unravel
# 3993 	 left to unravel
# 3991 	 left to unravel
# 3987 	 left to unravel
# 3986 	 left to unravel
# 3985 	 left to unravel
# 3982 	 left to unravel
# 3980 	 left to unravel
# 3979 	 left to unravel
# 3975 	 left to unravel
# 3974 	 left to unravel
# 3973 	 left to unravel
# 3972 	 left to unravel
# 3970 	 left to unravel
# 3969 	 left to unravel
# 3968 	 left to unravel
# 3966 	 left to unravel
# 3965 	 left to unravel
# 3964 	 left to unravel
# 3962 	 left to unravel
# 3961 	 left to unravel
# 3960 	 left to unravel
# 3959 	 left to unravel
# 3957 	 left to unravel
# 3955 	 left to unravel
# 3953 	 left to unravel
# 3952 	 left to unravel
# 3950 	 left to unravel
# 3948 	 left to unravel
# 3944 	 left to unravel
# 3942 	 left to unravel
# 3941 	 left to unravel
# 3940 	 left to unravel
# 3939 	 left to unravel
# 3938 	 left to unravel
# 3937 	 left to unravel
# 3936 	 left to unravel
# 3935 	 left to unravel
# 3934 	 left to unravel
# 3931 	 left to unravel
# 3927 	 left to unravel
# 3925 	 left to unravel
# 3920 	 left to unravel
# 3919 	 left to unravel
# 3918 	 left to unravel
# 3914 	 left to unravel
# 3912 	 left to unravel
# 3910 	 left to unravel
# 3909 	 left to unravel
# 3908 	 left to unravel
# 3907 	 left to unravel
# 3906 	 left to unravel
# 3904 	 left to unravel
# 3903 	 left to unravel
# 3902 	 left to unravel
# 3901 	 left to unravel
# 3898 	 left to unravel
# 3895 	 left to unravel
# 3894 	 left to unravel
# 3893 	 left to unravel
# 3891 	 left to unravel
# 3890 	 left to unravel
# 3888 	 left to unravel
# 3886 	 left to unravel
# 3885 	 left to unravel
# 3883 	 left to unravel
# 3881 	 left to unravel
# 3879 	 left to unravel
# 3876 	 left to unravel
# 3875 	 left to unravel
# 3874 	 left to unravel
# 3873 	 left to unravel
# 3872 	 left to unravel
# 3870 	 left to unravel
# 3869 	 left to unravel
# 3868 	 left to unravel
# 3867 	 left to unravel
# 3866 	 left to unravel
# 3865 	 left to unravel
# 3864 	 left to unravel
# 3863 	 left to unravel
# 3861 	 left to unravel
# 3859 	 left to unravel
# 3855 	 left to unravel
# 3854 	 left to unravel
# 3852 	 left to unravel
# 3848 	 left to unravel
# 3846 	 left to unravel
# 3845 	 left to unravel
# 3843 	 left to unravel
# 3842 	 left to unravel
# 3840 	 left to unravel
# 3839 	 left to unravel
# 3837 	 left to unravel
# 3835 	 left to unravel
# 3834 	 left to unravel
# 3833 	 left to unravel
# 3831 	 left to unravel
# 3829 	 left to unravel
# 3827 	 left to unravel
# 3826 	 left to unravel
# 3824 	 left to unravel
# 3822 	 left to unravel
# 3821 	 left to unravel
# 3817 	 left to unravel
# 3815 	 left to unravel
# 3814 	 left to unravel
# 3813 	 left to unravel
# 3812 	 left to unravel
# 3811 	 left to unravel
# 3810 	 left to unravel
# 3808 	 left to unravel
# 3807 	 left to unravel
# 3806 	 left to unravel
# 3805 	 left to unravel
# 3804 	 left to unravel
# 3803 	 left to unravel
# 3799 	 left to unravel
# 3797 	 left to unravel
# 3796 	 left to unravel
# 3795 	 left to unravel
# 3793 	 left to unravel
# 3792 	 left to unravel
# 3791 	 left to unravel
# 3790 	 left to unravel
# 3789 	 left to unravel
# 3787 	 left to unravel
# 3786 	 left to unravel
# 3785 	 left to unravel
# 3783 	 left to unravel
# 3782 	 left to unravel
# 3781 	 left to unravel
# 3780 	 left to unravel
# 3778 	 left to unravel
# 3777 	 left to unravel
# 3775 	 left to unravel
# 3773 	 left to unravel
# 3772 	 left to unravel
# 3769 	 left to unravel
# 3767 	 left to unravel
# 3766 	 left to unravel
# 3765 	 left to unravel
# 3763 	 left to unravel
# 3760 	 left to unravel
# 3759 	 left to unravel
# 3758 	 left to unravel
# 3757 	 left to unravel
# 3756 	 left to unravel
# 3755 	 left to unravel
# 3750 	 left to unravel
# 3747 	 left to unravel
# 3743 	 left to unravel
# 3742 	 left to unravel
# 3740 	 left to unravel
# 3739 	 left to unravel
# 3737 	 left to unravel
# 3736 	 left to unravel
# 3735 	 left to unravel
# 3734 	 left to unravel
# 3733 	 left to unravel
# 3730 	 left to unravel
# 3729 	 left to unravel
# 3726 	 left to unravel
# 3725 	 left to unravel
# 3724 	 left to unravel
# 3721 	 left to unravel
# 3718 	 left to unravel
# 3716 	 left to unravel
# 3714 	 left to unravel
# 3713 	 left to unravel
# 3712 	 left to unravel
# 3710 	 left to unravel
# 3709 	 left to unravel
# 3707 	 left to unravel
# 3706 	 left to unravel
# 3704 	 left to unravel
# 3702 	 left to unravel
# 3700 	 left to unravel
# 3698 	 left to unravel
# 3697 	 left to unravel
# 3695 	 left to unravel
# 3694 	 left to unravel
# 3692 	 left to unravel
# 3690 	 left to unravel
# 3689 	 left to unravel
# 3687 	 left to unravel
# 3686 	 left to unravel
# 3683 	 left to unravel
# 3681 	 left to unravel
# 3680 	 left to unravel
# 3679 	 left to unravel
# 3677 	 left to unravel
# 3676 	 left to unravel
# 3674 	 left to unravel
# 3672 	 left to unravel
# 3670 	 left to unravel
# 3669 	 left to unravel
# 3668 	 left to unravel
# 3667 	 left to unravel
# 3666 	 left to unravel
# 3664 	 left to unravel
# 3660 	 left to unravel
# 3658 	 left to unravel
# 3657 	 left to unravel
# 3655 	 left to unravel
# 3654 	 left to unravel
# 3653 	 left to unravel
# 3652 	 left to unravel
# 3650 	 left to unravel
# 3649 	 left to unravel
# 3645 	 left to unravel
# 3643 	 left to unravel
# 3642 	 left to unravel
# 3641 	 left to unravel
# 3640 	 left to unravel
# 3639 	 left to unravel
# 3638 	 left to unravel
# 3637 	 left to unravel
# 3636 	 left to unravel
# 3635 	 left to unravel
# 3633 	 left to unravel
# 3630 	 left to unravel
# 3629 	 left to unravel
# 3627 	 left to unravel
# 3625 	 left to unravel
# 3624 	 left to unravel
# 3623 	 left to unravel
# 3622 	 left to unravel
# 3618 	 left to unravel
# 3616 	 left to unravel
# 3614 	 left to unravel
# 3613 	 left to unravel
# 3609 	 left to unravel
# 3607 	 left to unravel
# 3606 	 left to unravel
# 3604 	 left to unravel
# 3603 	 left to unravel
# 3602 	 left to unravel
# 3601 	 left to unravel
# 3600 	 left to unravel
# 3599 	 left to unravel
# 3598 	 left to unravel
# 3597 	 left to unravel
# 3596 	 left to unravel
# 3594 	 left to unravel
# 3593 	 left to unravel
# 3592 	 left to unravel
# 3591 	 left to unravel
# 3590 	 left to unravel
# 3589 	 left to unravel
# 3588 	 left to unravel
# 3587 	 left to unravel
# 3585 	 left to unravel
# 3583 	 left to unravel
# 3581 	 left to unravel
# 3580 	 left to unravel
# 3578 	 left to unravel
# 3577 	 left to unravel
# 3576 	 left to unravel
# 3574 	 left to unravel
# 3571 	 left to unravel
# 3570 	 left to unravel
# 3568 	 left to unravel
# 3567 	 left to unravel
# 3566 	 left to unravel
# 3564 	 left to unravel
# 3563 	 left to unravel
# 3560 	 left to unravel
# 3558 	 left to unravel
# 3556 	 left to unravel
# 3555 	 left to unravel
# 3554 	 left to unravel
# 3550 	 left to unravel
# 3549 	 left to unravel
# 3547 	 left to unravel
# 3546 	 left to unravel
# 3545 	 left to unravel
# 3544 	 left to unravel
# 3543 	 left to unravel
# 3541 	 left to unravel
# 3540 	 left to unravel
# 3539 	 left to unravel
# 3538 	 left to unravel
# 3537 	 left to unravel
# 3536 	 left to unravel
# 3532 	 left to unravel
# 3531 	 left to unravel
# 3530 	 left to unravel
# 3529 	 left to unravel
# 3528 	 left to unravel
# 3526 	 left to unravel
# 3525 	 left to unravel
# 3524 	 left to unravel
# 3522 	 left to unravel
# 3521 	 left to unravel
# 3519 	 left to unravel
# 3516 	 left to unravel
# 3515 	 left to unravel
# 3514 	 left to unravel
# 3513 	 left to unravel
# 3512 	 left to unravel
# 3510 	 left to unravel
# 3509 	 left to unravel
# 3508 	 left to unravel
# 3507 	 left to unravel
# 3506 	 left to unravel
# 3504 	 left to unravel
# 3503 	 left to unravel
# 3501 	 left to unravel
# 3500 	 left to unravel
# 3499 	 left to unravel
# 3498 	 left to unravel
# 3493 	 left to unravel
# 3491 	 left to unravel
# 3490 	 left to unravel
# 3488 	 left to unravel
# 3487 	 left to unravel
# 3485 	 left to unravel
# 3484 	 left to unravel
# 3483 	 left to unravel
# 3482 	 left to unravel
# 3481 	 left to unravel
# 3480 	 left to unravel
# 3479 	 left to unravel
# 3478 	 left to unravel
# 3477 	 left to unravel
# 3476 	 left to unravel
# 3475 	 left to unravel
# 3474 	 left to unravel
# 3473 	 left to unravel
# 3471 	 left to unravel
# 3468 	 left to unravel
# 3467 	 left to unravel
# 3465 	 left to unravel
# 3463 	 left to unravel
# 3460 	 left to unravel
# 3459 	 left to unravel
# 3458 	 left to unravel
# 3457 	 left to unravel
# 3456 	 left to unravel
# 3455 	 left to unravel
# 3452 	 left to unravel
# 3451 	 left to unravel
# 3450 	 left to unravel
# 3449 	 left to unravel
# 3448 	 left to unravel
# 3447 	 left to unravel
# 3446 	 left to unravel
# 3443 	 left to unravel
# 3442 	 left to unravel
# 3441 	 left to unravel
# 3440 	 left to unravel
# 3438 	 left to unravel
# 3437 	 left to unravel
# 3434 	 left to unravel
# 3432 	 left to unravel
# 3431 	 left to unravel
# 3430 	 left to unravel
# 3429 	 left to unravel
# 3428 	 left to unravel
# 3427 	 left to unravel
# 3424 	 left to unravel
# 3423 	 left to unravel
# 3420 	 left to unravel
# 3419 	 left to unravel
# 3417 	 left to unravel
# 3416 	 left to unravel
# 3414 	 left to unravel
# 3413 	 left to unravel
# 3412 	 left to unravel
# 3411 	 left to unravel
# 3410 	 left to unravel
# 3409 	 left to unravel
# 3408 	 left to unravel
# 3407 	 left to unravel
# 3405 	 left to unravel
# 3404 	 left to unravel
# 3403 	 left to unravel
# 3402 	 left to unravel
# 3401 	 left to unravel
# 3400 	 left to unravel
# 3399 	 left to unravel
# 3398 	 left to unravel
# 3397 	 left to unravel
# 3396 	 left to unravel
# 3395 	 left to unravel
# 3393 	 left to unravel
# 3392 	 left to unravel
# 3390 	 left to unravel
# 3389 	 left to unravel
# 3387 	 left to unravel
# 3384 	 left to unravel
# 3383 	 left to unravel
# 3382 	 left to unravel
# 3381 	 left to unravel
# 3380 	 left to unravel
# 3378 	 left to unravel
# 3376 	 left to unravel
# 3375 	 left to unravel
# 3374 	 left to unravel
# 3373 	 left to unravel
# 3371 	 left to unravel
# 3367 	 left to unravel
# 3366 	 left to unravel
# 3363 	 left to unravel
# 3362 	 left to unravel
# 3361 	 left to unravel
# 3360 	 left to unravel
# 3357 	 left to unravel
# 3356 	 left to unravel
# 3355 	 left to unravel
# 3351 	 left to unravel
# 3348 	 left to unravel
# 3347 	 left to unravel
# 3345 	 left to unravel
# 3344 	 left to unravel
# 3341 	 left to unravel
# 3340 	 left to unravel
# 3339 	 left to unravel
# 3337 	 left to unravel
# 3333 	 left to unravel
# 3326 	 left to unravel
# 3320 	 left to unravel
# 3319 	 left to unravel
# 3318 	 left to unravel
# 3317 	 left to unravel
# 3315 	 left to unravel
# 3313 	 left to unravel
# 3311 	 left to unravel
# 3307 	 left to unravel
# 3306 	 left to unravel
# 3305 	 left to unravel
# 3304 	 left to unravel
# 3303 	 left to unravel
# 3301 	 left to unravel
# 3300 	 left to unravel
# 3298 	 left to unravel
# 3295 	 left to unravel
# 3290 	 left to unravel
# 3289 	 left to unravel
# 3287 	 left to unravel
# 3286 	 left to unravel
# 3285 	 left to unravel
# 3284 	 left to unravel
# 3283 	 left to unravel
# 3282 	 left to unravel
# 3280 	 left to unravel
# 3278 	 left to unravel
# 3276 	 left to unravel
# 3275 	 left to unravel
# 3273 	 left to unravel
# 3272 	 left to unravel
# 3271 	 left to unravel
# 3270 	 left to unravel
# 3268 	 left to unravel
# 3267 	 left to unravel
# 3265 	 left to unravel
# 3262 	 left to unravel
# 3261 	 left to unravel
# 3260 	 left to unravel
# 3259 	 left to unravel
# 3258 	 left to unravel
# 3257 	 left to unravel
# 3255 	 left to unravel
# 3253 	 left to unravel
# 3252 	 left to unravel
# 3251 	 left to unravel
# 3247 	 left to unravel
# 3246 	 left to unravel
# 3243 	 left to unravel
# 3242 	 left to unravel
# 3241 	 left to unravel
# 3240 	 left to unravel
# 3238 	 left to unravel
# 3236 	 left to unravel
# 3235 	 left to unravel
# 3232 	 left to unravel
# 3231 	 left to unravel
# 3229 	 left to unravel
# 3228 	 left to unravel
# 3227 	 left to unravel
# 3226 	 left to unravel
# 3224 	 left to unravel
# 3223 	 left to unravel
# 3222 	 left to unravel
# 3220 	 left to unravel
# 3219 	 left to unravel
# 3218 	 left to unravel
# 3216 	 left to unravel
# 3214 	 left to unravel
# 3213 	 left to unravel
# 3211 	 left to unravel
# 3210 	 left to unravel
# 3208 	 left to unravel
# 3206 	 left to unravel
# 3205 	 left to unravel
# 3203 	 left to unravel
# 3202 	 left to unravel
# 3201 	 left to unravel
# 3198 	 left to unravel
# 3197 	 left to unravel
# 3196 	 left to unravel
# 3195 	 left to unravel
# 3194 	 left to unravel
# 3193 	 left to unravel
# 3189 	 left to unravel
# 3187 	 left to unravel
# 3186 	 left to unravel
# 3185 	 left to unravel
# 3183 	 left to unravel
# 3182 	 left to unravel
# 3181 	 left to unravel
# 3180 	 left to unravel
# 3179 	 left to unravel
# 3178 	 left to unravel
# 3174 	 left to unravel
# 3173 	 left to unravel
# 3172 	 left to unravel
# 3170 	 left to unravel
# 3168 	 left to unravel
# 3167 	 left to unravel
# 3166 	 left to unravel
# 3164 	 left to unravel
# 3162 	 left to unravel
# 3161 	 left to unravel
# 3159 	 left to unravel
# 3158 	 left to unravel
# 3156 	 left to unravel
# 3155 	 left to unravel
# 3153 	 left to unravel
# 3152 	 left to unravel
# 3151 	 left to unravel
# 3150 	 left to unravel
# 3148 	 left to unravel
# 3147 	 left to unravel
# 3146 	 left to unravel
# 3145 	 left to unravel
# 3144 	 left to unravel
# 3143 	 left to unravel
# 3141 	 left to unravel
# 3140 	 left to unravel
# 3138 	 left to unravel
# 3137 	 left to unravel
# 3135 	 left to unravel
# 3134 	 left to unravel
# 3133 	 left to unravel
# 3131 	 left to unravel
# 3130 	 left to unravel
# 3129 	 left to unravel
# 3128 	 left to unravel
# 3127 	 left to unravel
# 3124 	 left to unravel
# 3123 	 left to unravel
# 3121 	 left to unravel
# 3120 	 left to unravel
# 3116 	 left to unravel
# 3115 	 left to unravel
# 3113 	 left to unravel
# 3112 	 left to unravel
# 3111 	 left to unravel
# 3109 	 left to unravel
# 3105 	 left to unravel
# 3104 	 left to unravel
# 3103 	 left to unravel
# 3102 	 left to unravel
# 3101 	 left to unravel
# 3100 	 left to unravel
# 3099 	 left to unravel
# 3097 	 left to unravel
# 3096 	 left to unravel
# 3094 	 left to unravel
# 3093 	 left to unravel
# 3091 	 left to unravel
# 3090 	 left to unravel
# 3089 	 left to unravel
# 3087 	 left to unravel
# 3086 	 left to unravel
# 3084 	 left to unravel
# 3083 	 left to unravel
# 3082 	 left to unravel
# 3081 	 left to unravel
# 3080 	 left to unravel
# 3078 	 left to unravel
# 3077 	 left to unravel
# 3076 	 left to unravel
# 3075 	 left to unravel
# 3074 	 left to unravel
# 3073 	 left to unravel
# 3070 	 left to unravel
# 3069 	 left to unravel
# 3068 	 left to unravel
# 3067 	 left to unravel
# 3063 	 left to unravel
# 3061 	 left to unravel
# 3058 	 left to unravel
# 3057 	 left to unravel
# 3055 	 left to unravel
# 3051 	 left to unravel
# 3050 	 left to unravel
# 3048 	 left to unravel
# 3047 	 left to unravel
# 3046 	 left to unravel
# 3044 	 left to unravel
# 3043 	 left to unravel
# 3041 	 left to unravel
# 3040 	 left to unravel
# 3039 	 left to unravel
# 3038 	 left to unravel
# 3036 	 left to unravel
# 3035 	 left to unravel
# 3032 	 left to unravel
# 3030 	 left to unravel
# 3025 	 left to unravel
# 3024 	 left to unravel
# 3021 	 left to unravel
# 3019 	 left to unravel
# 3018 	 left to unravel
# 3016 	 left to unravel
# 3014 	 left to unravel
# 3013 	 left to unravel
# 3012 	 left to unravel
# 3011 	 left to unravel
# 3009 	 left to unravel
# 3007 	 left to unravel
# 3006 	 left to unravel
# 3005 	 left to unravel
# 3004 	 left to unravel
# 3003 	 left to unravel
# 3002 	 left to unravel
# 3001 	 left to unravel
# 3000 	 left to unravel
# 2999 	 left to unravel
# 2994 	 left to unravel
# 2993 	 left to unravel
# 2992 	 left to unravel
# 2991 	 left to unravel
# 2990 	 left to unravel
# 2988 	 left to unravel
# 2986 	 left to unravel
# 2985 	 left to unravel
# 2983 	 left to unravel
# 2982 	 left to unravel
# 2981 	 left to unravel
# 2980 	 left to unravel
# 2978 	 left to unravel
# 2977 	 left to unravel
# 2976 	 left to unravel
# 2975 	 left to unravel
# 2971 	 left to unravel
# 2970 	 left to unravel
# 2969 	 left to unravel
# 2968 	 left to unravel
# 2966 	 left to unravel
# 2964 	 left to unravel
# 2962 	 left to unravel
# 2961 	 left to unravel
# 2960 	 left to unravel
# 2959 	 left to unravel
# 2958 	 left to unravel
# 2957 	 left to unravel
# 2956 	 left to unravel
# 2955 	 left to unravel
# 2954 	 left to unravel
# 2953 	 left to unravel
# 2952 	 left to unravel
# 2951 	 left to unravel
# 2950 	 left to unravel
# 2949 	 left to unravel
# 2947 	 left to unravel
# 2946 	 left to unravel
# 2943 	 left to unravel
# 2942 	 left to unravel
# 2940 	 left to unravel
# 2937 	 left to unravel
# 2936 	 left to unravel
# 2935 	 left to unravel
# 2934 	 left to unravel
# 2932 	 left to unravel
# 2930 	 left to unravel
# 2929 	 left to unravel
# 2927 	 left to unravel
# 2925 	 left to unravel
# 2924 	 left to unravel
# 2923 	 left to unravel
# 2922 	 left to unravel
# 2921 	 left to unravel
# 2919 	 left to unravel
# 2916 	 left to unravel
# 2915 	 left to unravel
# 2914 	 left to unravel
# 2913 	 left to unravel
# 2912 	 left to unravel
# 2911 	 left to unravel
# 2910 	 left to unravel
# 2909 	 left to unravel
# 2908 	 left to unravel
# 2907 	 left to unravel
# 2902 	 left to unravel
# 2901 	 left to unravel
# 2900 	 left to unravel
# 2898 	 left to unravel
# 2897 	 left to unravel
# 2896 	 left to unravel
# 2895 	 left to unravel
# 2893 	 left to unravel
# 2890 	 left to unravel
# 2889 	 left to unravel
# 2888 	 left to unravel
# 2887 	 left to unravel
# 2886 	 left to unravel
# 2885 	 left to unravel
# 2883 	 left to unravel
# 2881 	 left to unravel
# 2880 	 left to unravel
# 2879 	 left to unravel
# 2878 	 left to unravel
# 2877 	 left to unravel
# 2876 	 left to unravel
# 2875 	 left to unravel
# 2874 	 left to unravel
# 2873 	 left to unravel
# 2872 	 left to unravel
# 2871 	 left to unravel
# 2869 	 left to unravel
# 2865 	 left to unravel
# 2864 	 left to unravel
# 2863 	 left to unravel
# 2862 	 left to unravel
# 2860 	 left to unravel
# 2859 	 left to unravel
# 2858 	 left to unravel
# 2856 	 left to unravel
# 2855 	 left to unravel
# 2854 	 left to unravel
# 2851 	 left to unravel
# 2850 	 left to unravel
# 2848 	 left to unravel
# 2847 	 left to unravel
# 2846 	 left to unravel
# 2843 	 left to unravel
# 2842 	 left to unravel
# 2841 	 left to unravel
# 2838 	 left to unravel
# 2837 	 left to unravel
# 2835 	 left to unravel
# 2834 	 left to unravel
# 2833 	 left to unravel
# 2832 	 left to unravel
# 2831 	 left to unravel
# 2830 	 left to unravel
# 2829 	 left to unravel
# 2828 	 left to unravel
# 2826 	 left to unravel
# 2824 	 left to unravel
# 2822 	 left to unravel
# 2821 	 left to unravel
# 2820 	 left to unravel
# 2818 	 left to unravel
# 2817 	 left to unravel
# 2816 	 left to unravel
# 2815 	 left to unravel
# 2814 	 left to unravel
# 2813 	 left to unravel
# 2812 	 left to unravel
# 2809 	 left to unravel
# 2806 	 left to unravel
# 2805 	 left to unravel
# 2804 	 left to unravel
# 2803 	 left to unravel
# 2802 	 left to unravel
# 2801 	 left to unravel
# 2800 	 left to unravel
# 2799 	 left to unravel
# 2798 	 left to unravel
# 2797 	 left to unravel
# 2796 	 left to unravel
# 2795 	 left to unravel
# 2794 	 left to unravel
# 2793 	 left to unravel
# 2792 	 left to unravel
# 2791 	 left to unravel
# 2790 	 left to unravel
# 2786 	 left to unravel
# 2785 	 left to unravel
# 2784 	 left to unravel
# 2783 	 left to unravel
# 2782 	 left to unravel
# 2781 	 left to unravel
# 2779 	 left to unravel
# 2778 	 left to unravel
# 2777 	 left to unravel
# 2775 	 left to unravel
# 2774 	 left to unravel
# 2772 	 left to unravel
# 2769 	 left to unravel
# 2767 	 left to unravel
# 2766 	 left to unravel
# 2765 	 left to unravel
# 2761 	 left to unravel
# 2760 	 left to unravel
# 2759 	 left to unravel
# 2756 	 left to unravel
# 2755 	 left to unravel
# 2753 	 left to unravel
# 2752 	 left to unravel
# 2751 	 left to unravel
# 2749 	 left to unravel
# 2748 	 left to unravel
# 2747 	 left to unravel
# 2745 	 left to unravel
# 2744 	 left to unravel
# 2741 	 left to unravel
# 2740 	 left to unravel
# 2738 	 left to unravel
# 2736 	 left to unravel
# 2734 	 left to unravel
# 2733 	 left to unravel
# 2732 	 left to unravel
# 2731 	 left to unravel
# 2729 	 left to unravel
# 2728 	 left to unravel
# 2726 	 left to unravel
# 2723 	 left to unravel
# 2722 	 left to unravel
# 2721 	 left to unravel
# 2720 	 left to unravel
# 2719 	 left to unravel
# 2718 	 left to unravel
# 2717 	 left to unravel
# 2716 	 left to unravel
# 2715 	 left to unravel
# 2714 	 left to unravel
# 2713 	 left to unravel
# 2712 	 left to unravel
# 2711 	 left to unravel
# 2710 	 left to unravel
# 2709 	 left to unravel
# 2706 	 left to unravel
# 2705 	 left to unravel
# 2704 	 left to unravel
# 2703 	 left to unravel
# 2702 	 left to unravel
# 2701 	 left to unravel
# 2700 	 left to unravel
# 2699 	 left to unravel
# 2694 	 left to unravel
# 2691 	 left to unravel
# 2690 	 left to unravel
# 2689 	 left to unravel
# 2688 	 left to unravel
# 2687 	 left to unravel
# 2686 	 left to unravel
# 2685 	 left to unravel
# 2684 	 left to unravel
# 2683 	 left to unravel
# 2682 	 left to unravel
# 2681 	 left to unravel
# 2680 	 left to unravel
# 2678 	 left to unravel
# 2677 	 left to unravel
# 2676 	 left to unravel
# 2674 	 left to unravel
# 2673 	 left to unravel
# 2672 	 left to unravel
# 2671 	 left to unravel
# 2669 	 left to unravel
# 2668 	 left to unravel
# 2667 	 left to unravel
# 2665 	 left to unravel
# 2664 	 left to unravel
# 2663 	 left to unravel
# 2662 	 left to unravel
# 2660 	 left to unravel
# 2659 	 left to unravel
# 2657 	 left to unravel
# 2656 	 left to unravel
# 2655 	 left to unravel
# 2654 	 left to unravel
# 2653 	 left to unravel
# 2652 	 left to unravel
# 2651 	 left to unravel
# 2649 	 left to unravel
# 2648 	 left to unravel
# 2647 	 left to unravel
# 2646 	 left to unravel
# 2645 	 left to unravel
# 2644 	 left to unravel
# 2643 	 left to unravel
# 2642 	 left to unravel
# 2641 	 left to unravel
# 2640 	 left to unravel
# 2639 	 left to unravel
# 2638 	 left to unravel
# 2637 	 left to unravel
# 2636 	 left to unravel
# 2635 	 left to unravel
# 2634 	 left to unravel
# 2628 	 left to unravel
# 2627 	 left to unravel
# 2625 	 left to unravel
# 2624 	 left to unravel
# 2622 	 left to unravel
# 2621 	 left to unravel
# 2619 	 left to unravel
# 2617 	 left to unravel
# 2616 	 left to unravel
# 2614 	 left to unravel
# 2613 	 left to unravel
# 2612 	 left to unravel
# 2611 	 left to unravel
# 2610 	 left to unravel
# 2609 	 left to unravel
# 2608 	 left to unravel
# 2607 	 left to unravel
# 2606 	 left to unravel
# 2605 	 left to unravel
# 2603 	 left to unravel
# 2601 	 left to unravel
# 2598 	 left to unravel
# 2595 	 left to unravel
# 2594 	 left to unravel
# 2590 	 left to unravel
# 2589 	 left to unravel
# 2587 	 left to unravel
# 2586 	 left to unravel
# 2585 	 left to unravel
# 2582 	 left to unravel
# 2581 	 left to unravel
# 2580 	 left to unravel
# 2579 	 left to unravel
# 2578 	 left to unravel
# 2576 	 left to unravel
# 2575 	 left to unravel
# 2574 	 left to unravel
# 2573 	 left to unravel
# 2572 	 left to unravel
# 2569 	 left to unravel
# 2568 	 left to unravel
# 2567 	 left to unravel
# 2566 	 left to unravel
# 2565 	 left to unravel
# 2563 	 left to unravel
# 2562 	 left to unravel
# 2561 	 left to unravel
# 2560 	 left to unravel
# 2559 	 left to unravel
# 2557 	 left to unravel
# 2555 	 left to unravel
# 2554 	 left to unravel
# 2553 	 left to unravel
# 2552 	 left to unravel
# 2551 	 left to unravel
# 2550 	 left to unravel
# 2549 	 left to unravel
# 2546 	 left to unravel
# 2544 	 left to unravel
# 2543 	 left to unravel
# 2542 	 left to unravel
# 2541 	 left to unravel
# 2538 	 left to unravel
# 2537 	 left to unravel
# 2536 	 left to unravel
# 2535 	 left to unravel
# 2534 	 left to unravel
# 2533 	 left to unravel
# 2532 	 left to unravel
# 2531 	 left to unravel
# 2530 	 left to unravel
# 2527 	 left to unravel
# 2524 	 left to unravel
# 2523 	 left to unravel
# 2522 	 left to unravel
# 2521 	 left to unravel
# 2520 	 left to unravel
# 2516 	 left to unravel
# 2514 	 left to unravel
# 2513 	 left to unravel
# 2511 	 left to unravel
# 2509 	 left to unravel
# 2508 	 left to unravel
# 2507 	 left to unravel
# 2506 	 left to unravel
# 2504 	 left to unravel
# 2501 	 left to unravel
# 2500 	 left to unravel
# 2499 	 left to unravel
# 2498 	 left to unravel
# 2497 	 left to unravel
# 2495 	 left to unravel
# 2494 	 left to unravel
# 2493 	 left to unravel
# 2492 	 left to unravel
# 2491 	 left to unravel
# 2490 	 left to unravel
# 2489 	 left to unravel
# 2488 	 left to unravel
# 2486 	 left to unravel
# 2484 	 left to unravel
# 2482 	 left to unravel
# 2481 	 left to unravel
# 2480 	 left to unravel
# 2479 	 left to unravel
# 2478 	 left to unravel
# 2477 	 left to unravel
# 2476 	 left to unravel
# 2475 	 left to unravel
# 2474 	 left to unravel
# 2473 	 left to unravel
# 2472 	 left to unravel
# 2471 	 left to unravel
# 2470 	 left to unravel
# 2469 	 left to unravel
# 2467 	 left to unravel
# 2466 	 left to unravel
# 2465 	 left to unravel
# 2464 	 left to unravel
# 2463 	 left to unravel
# 2461 	 left to unravel
# 2459 	 left to unravel
# 2458 	 left to unravel
# 2457 	 left to unravel
# 2456 	 left to unravel
# 2454 	 left to unravel
# 2453 	 left to unravel
# 2451 	 left to unravel
# 2450 	 left to unravel
# 2448 	 left to unravel
# 2447 	 left to unravel
# 2445 	 left to unravel
# 2444 	 left to unravel
# 2443 	 left to unravel
# 2442 	 left to unravel
# 2441 	 left to unravel
# 2440 	 left to unravel
# 2439 	 left to unravel
# 2438 	 left to unravel
# 2437 	 left to unravel
# 2436 	 left to unravel
# 2435 	 left to unravel
# 2434 	 left to unravel
# 2433 	 left to unravel
# 2432 	 left to unravel
# 2431 	 left to unravel
# 2429 	 left to unravel
# 2428 	 left to unravel
# 2427 	 left to unravel
# 2426 	 left to unravel
# 2425 	 left to unravel
# 2424 	 left to unravel
# 2423 	 left to unravel
# 2422 	 left to unravel
# 2421 	 left to unravel
# 2420 	 left to unravel
# 2419 	 left to unravel
# 2418 	 left to unravel
# 2416 	 left to unravel
# 2414 	 left to unravel
# 2412 	 left to unravel
# 2409 	 left to unravel
# 2407 	 left to unravel
# 2406 	 left to unravel
# 2405 	 left to unravel
# 2404 	 left to unravel
# 2402 	 left to unravel
# 2401 	 left to unravel
# 2400 	 left to unravel
# 2398 	 left to unravel
# 2397 	 left to unravel
# 2393 	 left to unravel
# 2391 	 left to unravel
# 2390 	 left to unravel
# 2389 	 left to unravel
# 2388 	 left to unravel
# 2387 	 left to unravel
# 2386 	 left to unravel
# 2385 	 left to unravel
# 2384 	 left to unravel
# 2381 	 left to unravel
# 2380 	 left to unravel
# 2379 	 left to unravel
# 2378 	 left to unravel
# 2377 	 left to unravel
# 2374 	 left to unravel
# 2373 	 left to unravel
# 2372 	 left to unravel
# 2369 	 left to unravel
# 2368 	 left to unravel
# 2366 	 left to unravel
# 2365 	 left to unravel
# 2363 	 left to unravel
# 2362 	 left to unravel
# 2360 	 left to unravel
# 2358 	 left to unravel
# 2357 	 left to unravel
# 2356 	 left to unravel
# 2355 	 left to unravel
# 2354 	 left to unravel
# 2353 	 left to unravel
# 2352 	 left to unravel
# 2350 	 left to unravel
# 2349 	 left to unravel
# 2348 	 left to unravel
# 2347 	 left to unravel
# 2346 	 left to unravel
# 2345 	 left to unravel
# 2344 	 left to unravel
# 2343 	 left to unravel
# 2342 	 left to unravel
# 2340 	 left to unravel
# 2339 	 left to unravel
# 2338 	 left to unravel
# 2336 	 left to unravel
# 2335 	 left to unravel
# 2334 	 left to unravel
# 2333 	 left to unravel
# 2332 	 left to unravel
# 2327 	 left to unravel
# 2324 	 left to unravel
# 2323 	 left to unravel
# 2322 	 left to unravel
# 2320 	 left to unravel
# 2318 	 left to unravel
# 2317 	 left to unravel
# 2315 	 left to unravel
# 2310 	 left to unravel
# 2309 	 left to unravel
# 2307 	 left to unravel
# 2306 	 left to unravel
# 2304 	 left to unravel
# 2303 	 left to unravel
# 2302 	 left to unravel
# 2301 	 left to unravel
# 2300 	 left to unravel
# 2299 	 left to unravel
# 2298 	 left to unravel
# 2297 	 left to unravel
# 2296 	 left to unravel
# 2295 	 left to unravel
# 2294 	 left to unravel
# 2292 	 left to unravel
# 2290 	 left to unravel
# 2289 	 left to unravel
# 2287 	 left to unravel
# 2285 	 left to unravel
# 2284 	 left to unravel
# 2282 	 left to unravel
# 2281 	 left to unravel
# 2280 	 left to unravel
# 2279 	 left to unravel
# 2277 	 left to unravel
# 2276 	 left to unravel
# 2275 	 left to unravel
# 2274 	 left to unravel
# 2273 	 left to unravel
# 2272 	 left to unravel
# 2270 	 left to unravel
# 2268 	 left to unravel
# 2267 	 left to unravel
# 2266 	 left to unravel
# 2265 	 left to unravel
# 2264 	 left to unravel
# 2263 	 left to unravel
# 2262 	 left to unravel
# 2261 	 left to unravel
# 2260 	 left to unravel
# 2259 	 left to unravel
# 2258 	 left to unravel
# 2257 	 left to unravel
# 2256 	 left to unravel
# 2255 	 left to unravel
# 2254 	 left to unravel
# 2253 	 left to unravel
# 2252 	 left to unravel
# 2251 	 left to unravel
# 2250 	 left to unravel
# 2249 	 left to unravel
# 2248 	 left to unravel
# 2247 	 left to unravel
# 2246 	 left to unravel
# 2245 	 left to unravel
# 2244 	 left to unravel
# 2243 	 left to unravel
# 2242 	 left to unravel
# 2241 	 left to unravel
# 2240 	 left to unravel
# 2239 	 left to unravel
# 2238 	 left to unravel
# 2237 	 left to unravel
# 2236 	 left to unravel
# 2235 	 left to unravel
# 2232 	 left to unravel
# 2231 	 left to unravel
# 2230 	 left to unravel
# 2229 	 left to unravel
# 2228 	 left to unravel
# 2227 	 left to unravel
# 2226 	 left to unravel
# 2224 	 left to unravel
# 2223 	 left to unravel
# 2222 	 left to unravel
# 2220 	 left to unravel
# 2219 	 left to unravel
# 2218 	 left to unravel
# 2217 	 left to unravel
# 2216 	 left to unravel
# 2215 	 left to unravel
# 2214 	 left to unravel
# 2213 	 left to unravel
# 2212 	 left to unravel
# 2211 	 left to unravel
# 2210 	 left to unravel
# 2208 	 left to unravel
# 2207 	 left to unravel
# 2204 	 left to unravel
# 2203 	 left to unravel
# 2202 	 left to unravel
# 2201 	 left to unravel
# 2199 	 left to unravel
# 2198 	 left to unravel
# 2197 	 left to unravel
# 2196 	 left to unravel
# 2195 	 left to unravel
# 2194 	 left to unravel
# 2191 	 left to unravel
# 2190 	 left to unravel
# 2187 	 left to unravel
# 2185 	 left to unravel
# 2184 	 left to unravel
# 2183 	 left to unravel
# 2182 	 left to unravel
# 2181 	 left to unravel
# 2180 	 left to unravel
# 2179 	 left to unravel
# 2178 	 left to unravel
# 2177 	 left to unravel
# 2174 	 left to unravel
# 2173 	 left to unravel
# 2172 	 left to unravel
# 2171 	 left to unravel
# 2170 	 left to unravel
# 2169 	 left to unravel
# 2168 	 left to unravel
# 2167 	 left to unravel
# 2166 	 left to unravel
# 2165 	 left to unravel
# 2164 	 left to unravel
# 2162 	 left to unravel
# 2161 	 left to unravel
# 2160 	 left to unravel
# 2158 	 left to unravel
# 2157 	 left to unravel
# 2156 	 left to unravel
# 2154 	 left to unravel
# 2153 	 left to unravel
# 2152 	 left to unravel
# 2151 	 left to unravel
# 2149 	 left to unravel
# 2148 	 left to unravel
# 2147 	 left to unravel
# 2146 	 left to unravel
# 2145 	 left to unravel
# 2144 	 left to unravel
# 2143 	 left to unravel
# 2141 	 left to unravel
# 2140 	 left to unravel
# 2139 	 left to unravel
# 2138 	 left to unravel
# 2137 	 left to unravel
# 2136 	 left to unravel
# 2135 	 left to unravel
# 2134 	 left to unravel
# 2133 	 left to unravel
# 2132 	 left to unravel
# 2131 	 left to unravel
# 2128 	 left to unravel
# 2127 	 left to unravel
# 2125 	 left to unravel
# 2124 	 left to unravel
# 2122 	 left to unravel
# 2121 	 left to unravel
# 2120 	 left to unravel
# 2119 	 left to unravel
# 2118 	 left to unravel
# 2117 	 left to unravel
# 2116 	 left to unravel
# 2114 	 left to unravel
# 2113 	 left to unravel
# 2112 	 left to unravel
# 2111 	 left to unravel
# 2110 	 left to unravel
# 2109 	 left to unravel
# 2108 	 left to unravel
# 2107 	 left to unravel
# 2104 	 left to unravel
# 2103 	 left to unravel
# 2102 	 left to unravel
# 2101 	 left to unravel
# 2100 	 left to unravel
# 2099 	 left to unravel
# 2098 	 left to unravel
# 2096 	 left to unravel
# 2094 	 left to unravel
# 2093 	 left to unravel
# 2092 	 left to unravel
# 2091 	 left to unravel
# 2089 	 left to unravel
# 2088 	 left to unravel
# 2087 	 left to unravel
# 2086 	 left to unravel
# 2085 	 left to unravel
# 2084 	 left to unravel
# 2083 	 left to unravel
# 2082 	 left to unravel
# 2081 	 left to unravel
# 2080 	 left to unravel
# 2078 	 left to unravel
# 2077 	 left to unravel
# 2076 	 left to unravel
# 2075 	 left to unravel
# 2074 	 left to unravel
# 2073 	 left to unravel
# 2072 	 left to unravel
# 2071 	 left to unravel
# 2070 	 left to unravel
# 2068 	 left to unravel
# 2067 	 left to unravel
# 2066 	 left to unravel
# 2065 	 left to unravel
# 2064 	 left to unravel
# 2063 	 left to unravel
# 2062 	 left to unravel
# 2060 	 left to unravel
# 2059 	 left to unravel
# 2057 	 left to unravel
# 2056 	 left to unravel
# 2054 	 left to unravel
# 2052 	 left to unravel
# 2050 	 left to unravel
# 2049 	 left to unravel
# 2048 	 left to unravel
# 2046 	 left to unravel
# 2045 	 left to unravel
# 2043 	 left to unravel
# 2042 	 left to unravel
# ...
# 1887 	 left to unravel
# 1886 	 left to unravel
# 1884 	 left to unravel
# 1883 	 left to unravel
# 1882 	 left to unravel
# 1881 	 left to unravel
# 1880 	 left to unravel
# 1879 	 left to unravel
# 1878 	 left to unravel
# 1877 	 left to unravel
# 1875 	 left to unravel
# 1874 	 left to unravel
# 1873 	 left to unravel
# 1872 	 left to unravel
# 1871 	 left to unravel
# 1870 	 left to unravel
# 1868 	 left to unravel
# 1867 	 left to unravel
# 1866 	 left to unravel
# 1864 	 left to unravel
# 1863 	 left to unravel
# 1861 	 left to unravel
# 1860 	 left to unravel
# 1859 	 left to unravel
# 1858 	 left to unravel
# 1857 	 left to unravel
# 1855 	 left to unravel
# 1854 	 left to unravel
# 1853 	 left to unravel
# 1852 	 left to unravel
# 1850 	 left to unravel
# 1849 	 left to unravel
# 1847 	 left to unravel
# 1846 	 left to unravel
# 1845 	 left to unravel
# 1844 	 left to unravel
# 1843 	 left to unravel
# 1842 	 left to unravel
# 1841 	 left to unravel
# 1840 	 left to unravel
# 1839 	 left to unravel
# 1838 	 left to unravel
# 1837 	 left to unravel
# 1836 	 left to unravel
# 1835 	 left to unravel
# 1833 	 left to unravel
# 1831 	 left to unravel
# 1830 	 left to unravel
# 1829 	 left to unravel
# 1828 	 left to unravel
# 1827 	 left to unravel
# 1826 	 left to unravel
# 1825 	 left to unravel
# 1824 	 left to unravel
# 1823 	 left to unravel
# 1822 	 left to unravel
# 1821 	 left to unravel
# 1820 	 left to unravel
# 1819 	 left to unravel
# 1818 	 left to unravel
# 1817 	 left to unravel
# 1816 	 left to unravel
# 1815 	 left to unravel
# 1814 	 left to unravel
# 1813 	 left to unravel
# 1812 	 left to unravel
# 1811 	 left to unravel
# 1810 	 left to unravel
# 1809 	 left to unravel
# 1808 	 left to unravel
# 1807 	 left to unravel
# 1806 	 left to unravel
# 1805 	 left to unravel
# 1804 	 left to unravel
# 1803 	 left to unravel
# 1802 	 left to unravel
# 1800 	 left to unravel
# 1799 	 left to unravel
# 1796 	 left to unravel
# 1795 	 left to unravel
# 1794 	 left to unravel
# 1793 	 left to unravel
# 1791 	 left to unravel
# 1790 	 left to unravel
# 1789 	 left to unravel
# 1788 	 left to unravel
# 1786 	 left to unravel
# 1785 	 left to unravel
# 1784 	 left to unravel
# 1783 	 left to unravel
# 1781 	 left to unravel
# 1779 	 left to unravel
# 1778 	 left to unravel
# 1776 	 left to unravel
# 1775 	 left to unravel
# 1774 	 left to unravel
# 1773 	 left to unravel
# 1771 	 left to unravel
# 1770 	 left to unravel
# 1769 	 left to unravel
# 1768 	 left to unravel
# 1766 	 left to unravel
# 1765 	 left to unravel
# 1763 	 left to unravel
# 1762 	 left to unravel
# 1761 	 left to unravel
# 1760 	 left to unravel
# 1759 	 left to unravel
# 1758 	 left to unravel
# 1757 	 left to unravel
# 1756 	 left to unravel
# 1755 	 left to unravel
# 1753 	 left to unravel
# 1752 	 left to unravel
# 1751 	 left to unravel
# 1750 	 left to unravel
# 1749 	 left to unravel
# 1748 	 left to unravel
# 1747 	 left to unravel
# 1746 	 left to unravel
# 1745 	 left to unravel
# 1744 	 left to unravel
# 1743 	 left to unravel
# 1742 	 left to unravel
# 1739 	 left to unravel
# 1738 	 left to unravel
# 1737 	 left to unravel
# 1735 	 left to unravel
# 1734 	 left to unravel
# 1733 	 left to unravel
# 1732 	 left to unravel
# 1729 	 left to unravel
# 1728 	 left to unravel
# 1727 	 left to unravel
# 1726 	 left to unravel
# 1725 	 left to unravel
# 1723 	 left to unravel
# 1722 	 left to unravel
# 1721 	 left to unravel
# 1720 	 left to unravel
# 1719 	 left to unravel
# 1718 	 left to unravel
# 1717 	 left to unravel
# 1716 	 left to unravel
# 1715 	 left to unravel
# 1714 	 left to unravel
# 1712 	 left to unravel
# 1711 	 left to unravel
# 1710 	 left to unravel
# 1709 	 left to unravel
# 1708 	 left to unravel
# 1707 	 left to unravel
# 1706 	 left to unravel
# 1705 	 left to unravel
# 1704 	 left to unravel
# 1703 	 left to unravel
# 1702 	 left to unravel
# 1701 	 left to unravel
# 1700 	 left to unravel
# 1699 	 left to unravel
# 1697 	 left to unravel
# 1696 	 left to unravel
# 1695 	 left to unravel
# 1693 	 left to unravel
# 1692 	 left to unravel
# 1691 	 left to unravel
# 1690 	 left to unravel
# 1689 	 left to unravel
# 1688 	 left to unravel
# 1687 	 left to unravel
# 1686 	 left to unravel
# 1685 	 left to unravel
# 1684 	 left to unravel
# 1683 	 left to unravel
# 1682 	 left to unravel
# 1681 	 left to unravel
# 1679 	 left to unravel
# 1678 	 left to unravel
# 1677 	 left to unravel
# 1676 	 left to unravel
# 1675 	 left to unravel
# 1674 	 left to unravel
# 1673 	 left to unravel
# 1672 	 left to unravel
# 1671 	 left to unravel
# 1669 	 left to unravel
# 1668 	 left to unravel
# 1667 	 left to unravel
# 1666 	 left to unravel
# 1665 	 left to unravel
# 1664 	 left to unravel
# 1663 	 left to unravel
# 1662 	 left to unravel
# 1661 	 left to unravel
# 1660 	 left to unravel
# 1658 	 left to unravel
# 1656 	 left to unravel
# 1654 	 left to unravel
# 1653 	 left to unravel
# 1652 	 left to unravel
# 1651 	 left to unravel
# 1650 	 left to unravel
# 1649 	 left to unravel
# 1648 	 left to unravel
# 1647 	 left to unravel
# 1646 	 left to unravel
# 1645 	 left to unravel
# 1644 	 left to unravel
# 1643 	 left to unravel
# 1642 	 left to unravel
# 1641 	 left to unravel
# 1640 	 left to unravel
# 1639 	 left to unravel
# 1637 	 left to unravel
# 1636 	 left to unravel
# 1635 	 left to unravel
# 1634 	 left to unravel
# 1633 	 left to unravel
# 1632 	 left to unravel
# 1630 	 left to unravel
# 1628 	 left to unravel
# 1627 	 left to unravel
# 1626 	 left to unravel
# 1624 	 left to unravel
# 1622 	 left to unravel
# 1621 	 left to unravel
# 1620 	 left to unravel
# 1619 	 left to unravel
# 1618 	 left to unravel
# 1617 	 left to unravel
# 1616 	 left to unravel
# 1615 	 left to unravel
# 1613 	 left to unravel
# 1611 	 left to unravel
# 1610 	 left to unravel
# 1609 	 left to unravel
# 1608 	 left to unravel
# 1607 	 left to unravel
# 1606 	 left to unravel
# 1605 	 left to unravel
# 1604 	 left to unravel
# 1603 	 left to unravel
# 1602 	 left to unravel
# 1601 	 left to unravel
# 1600 	 left to unravel
# 1599 	 left to unravel
# 1598 	 left to unravel
# 1597 	 left to unravel
# 1596 	 left to unravel
# 1595 	 left to unravel
# 1594 	 left to unravel
# 1593 	 left to unravel
# 1591 	 left to unravel
# 1590 	 left to unravel
# 1589 	 left to unravel
# 1588 	 left to unravel
# 1587 	 left to unravel
# 1586 	 left to unravel
# 1585 	 left to unravel
# 1584 	 left to unravel
# 1583 	 left to unravel
# 1582 	 left to unravel
# 1581 	 left to unravel
# 1580 	 left to unravel
# 1579 	 left to unravel
# 1578 	 left to unravel
# 1577 	 left to unravel
# 1575 	 left to unravel
# 1574 	 left to unravel
# 1572 	 left to unravel
# 1571 	 left to unravel
# 1570 	 left to unravel
# 1568 	 left to unravel
# 1567 	 left to unravel
# 1565 	 left to unravel
# 1564 	 left to unravel
# 1563 	 left to unravel
# 1562 	 left to unravel
# 1560 	 left to unravel
# 1559 	 left to unravel
# 1558 	 left to unravel
# 1557 	 left to unravel
# 1554 	 left to unravel
# 1553 	 left to unravel
# 1552 	 left to unravel
# 1551 	 left to unravel
# 1550 	 left to unravel
# 1548 	 left to unravel
# 1547 	 left to unravel
# 1546 	 left to unravel
# 1545 	 left to unravel
# 1544 	 left to unravel
# 1543 	 left to unravel
# 1542 	 left to unravel
# 1541 	 left to unravel
# 1540 	 left to unravel
# 1539 	 left to unravel
# 1538 	 left to unravel
# 1537 	 left to unravel
# 1536 	 left to unravel
# 1534 	 left to unravel
# 1533 	 left to unravel
# 1532 	 left to unravel
# 1531 	 left to unravel
# 1530 	 left to unravel
# 1529 	 left to unravel
# 1528 	 left to unravel
# 1527 	 left to unravel
# 1526 	 left to unravel
# 1525 	 left to unravel
# 1524 	 left to unravel
# 1523 	 left to unravel
# 1522 	 left to unravel
# 1520 	 left to unravel
# 1519 	 left to unravel
# 1518 	 left to unravel
# 1517 	 left to unravel
# 1515 	 left to unravel
# 1514 	 left to unravel
# 1513 	 left to unravel
# 1512 	 left to unravel
# 1511 	 left to unravel
# 1510 	 left to unravel
# 1509 	 left to unravel
# 1508 	 left to unravel
# 1507 	 left to unravel
# 1506 	 left to unravel
# 1504 	 left to unravel
# 1502 	 left to unravel
# 1501 	 left to unravel
# 1500 	 left to unravel
# 1499 	 left to unravel
# 1498 	 left to unravel
# 1497 	 left to unravel
# 1494 	 left to unravel
# 1493 	 left to unravel
# 1492 	 left to unravel
# 1491 	 left to unravel
# 1490 	 left to unravel
# 1489 	 left to unravel
# 1488 	 left to unravel
# 1487 	 left to unravel
# 1486 	 left to unravel
# 1485 	 left to unravel
# 1484 	 left to unravel
# 1483 	 left to unravel
# 1482 	 left to unravel
# 1481 	 left to unravel
# 1480 	 left to unravel
# 1479 	 left to unravel
# 1478 	 left to unravel
# 1477 	 left to unravel
# 1476 	 left to unravel
# 1475 	 left to unravel
# 1474 	 left to unravel
# 1473 	 left to unravel
# 1472 	 left to unravel
# 1471 	 left to unravel
# 1470 	 left to unravel
# 1468 	 left to unravel
# 1467 	 left to unravel
# 1466 	 left to unravel
# 1465 	 left to unravel
# 1464 	 left to unravel
# 1463 	 left to unravel
# 1462 	 left to unravel
# 1461 	 left to unravel
# 1459 	 left to unravel
# 1458 	 left to unravel
# 1456 	 left to unravel
# 1455 	 left to unravel
# 1454 	 left to unravel
# 1452 	 left to unravel
# 1451 	 left to unravel
# 1450 	 left to unravel
# 1449 	 left to unravel
# 1448 	 left to unravel
# 1447 	 left to unravel
# 1446 	 left to unravel
# 1445 	 left to unravel
# 1444 	 left to unravel
# 1443 	 left to unravel
# 1442 	 left to unravel
# 1441 	 left to unravel
# 1439 	 left to unravel
# 1438 	 left to unravel
# 1437 	 left to unravel
# 1436 	 left to unravel
# 1435 	 left to unravel
# 1434 	 left to unravel
# 1433 	 left to unravel
# 1432 	 left to unravel
# 1431 	 left to unravel
# 1430 	 left to unravel
# 1428 	 left to unravel
# 1427 	 left to unravel
# 1426 	 left to unravel
# 1425 	 left to unravel
# 1424 	 left to unravel
# 1423 	 left to unravel
# 1422 	 left to unravel
# 1421 	 left to unravel
# 1420 	 left to unravel
# 1419 	 left to unravel
# 1418 	 left to unravel
# 1417 	 left to unravel
# 1416 	 left to unravel
# 1415 	 left to unravel
# 1414 	 left to unravel
# 1413 	 left to unravel
# 1412 	 left to unravel
# 1411 	 left to unravel
# 1410 	 left to unravel
# 1409 	 left to unravel
# 1408 	 left to unravel
# 1406 	 left to unravel
# 1405 	 left to unravel
# 1404 	 left to unravel
# 1403 	 left to unravel
# 1402 	 left to unravel
# 1401 	 left to unravel
# 1399 	 left to unravel
# 1398 	 left to unravel
# 1396 	 left to unravel
# 1395 	 left to unravel
# 1394 	 left to unravel
# 1393 	 left to unravel
# 1392 	 left to unravel
# 1391 	 left to unravel
# 1390 	 left to unravel
# 1389 	 left to unravel
# 1388 	 left to unravel
# 1387 	 left to unravel
# 1386 	 left to unravel
# 1385 	 left to unravel
# 1384 	 left to unravel
# 1382 	 left to unravel
# 1381 	 left to unravel
# 1380 	 left to unravel
# 1378 	 left to unravel
# 1377 	 left to unravel
# 1375 	 left to unravel
# 1373 	 left to unravel
# 1372 	 left to unravel
# 1371 	 left to unravel
# 1370 	 left to unravel
# 1369 	 left to unravel
# 1368 	 left to unravel
# 1367 	 left to unravel
# 1366 	 left to unravel
# 1365 	 left to unravel
# 1364 	 left to unravel
# 1362 	 left to unravel
# 1361 	 left to unravel
# 1360 	 left to unravel
# 1359 	 left to unravel
# 1358 	 left to unravel
# 1357 	 left to unravel
# 1356 	 left to unravel
# 1355 	 left to unravel
# 1353 	 left to unravel
# 1351 	 left to unravel
# 1350 	 left to unravel
# 1349 	 left to unravel
# 1348 	 left to unravel
# 1347 	 left to unravel
# 1346 	 left to unravel
# 1345 	 left to unravel
# 1344 	 left to unravel
# 1343 	 left to unravel
# 1342 	 left to unravel
# 1341 	 left to unravel
# 1340 	 left to unravel
# 1339 	 left to unravel
# 1338 	 left to unravel
# 1337 	 left to unravel
# 1336 	 left to unravel
# 1334 	 left to unravel
# 1333 	 left to unravel
# 1332 	 left to unravel
# 1331 	 left to unravel
# 1330 	 left to unravel
# 1328 	 left to unravel
# 1327 	 left to unravel
# 1326 	 left to unravel
# 1325 	 left to unravel
# 1324 	 left to unravel
# 1323 	 left to unravel
# 1322 	 left to unravel
# 1321 	 left to unravel
# 1320 	 left to unravel
# 1319 	 left to unravel
# 1318 	 left to unravel
# 1317 	 left to unravel
# 1316 	 left to unravel
# 1315 	 left to unravel
# 1314 	 left to unravel
# 1313 	 left to unravel
# 1312 	 left to unravel
# 1311 	 left to unravel
# 1310 	 left to unravel
# 1309 	 left to unravel
# 1307 	 left to unravel
# 1306 	 left to unravel
# 1305 	 left to unravel
# 1304 	 left to unravel
# 1303 	 left to unravel
# 1301 	 left to unravel
# 1300 	 left to unravel
# 1299 	 left to unravel
# 1298 	 left to unravel
# 1297 	 left to unravel
# 1296 	 left to unravel
# 1295 	 left to unravel
# 1294 	 left to unravel
# 1291 	 left to unravel
# 1290 	 left to unravel
# 1289 	 left to unravel
# 1288 	 left to unravel
# 1287 	 left to unravel
# 1286 	 left to unravel
# 1285 	 left to unravel
# 1283 	 left to unravel
# 1282 	 left to unravel
# 1280 	 left to unravel
# 1277 	 left to unravel
# 1276 	 left to unravel
# 1275 	 left to unravel
# 1274 	 left to unravel
# 1273 	 left to unravel
# 1272 	 left to unravel
# 1270 	 left to unravel
# 1269 	 left to unravel
# 1268 	 left to unravel
# 1267 	 left to unravel
# 1266 	 left to unravel
# 1265 	 left to unravel
# 1264 	 left to unravel
# 1263 	 left to unravel
# 1262 	 left to unravel
# 1261 	 left to unravel
# 1260 	 left to unravel
# 1259 	 left to unravel
# 1258 	 left to unravel
# 1255 	 left to unravel
# 1254 	 left to unravel
# 1253 	 left to unravel
# 1252 	 left to unravel
# 1251 	 left to unravel
# 1250 	 left to unravel
# 1249 	 left to unravel
# 1248 	 left to unravel
# 1247 	 left to unravel
# 1246 	 left to unravel
# 1245 	 left to unravel
# 1244 	 left to unravel
# 1243 	 left to unravel
# 1242 	 left to unravel
# 1241 	 left to unravel
# 1240 	 left to unravel
# 1239 	 left to unravel
# 1238 	 left to unravel
# 1237 	 left to unravel
# 1235 	 left to unravel
# 1234 	 left to unravel
# 1233 	 left to unravel
# 1232 	 left to unravel
# 1231 	 left to unravel
# 1230 	 left to unravel
# 1229 	 left to unravel
# 1228 	 left to unravel
# 1226 	 left to unravel
# 1225 	 left to unravel
# 1224 	 left to unravel
# 1223 	 left to unravel
# 1222 	 left to unravel
# 1221 	 left to unravel
# 1220 	 left to unravel
# 1219 	 left to unravel
# 1218 	 left to unravel
# 1217 	 left to unravel
# 1216 	 left to unravel
# 1215 	 left to unravel
# 1214 	 left to unravel
# 1212 	 left to unravel
# 1211 	 left to unravel
# 1209 	 left to unravel
# 1207 	 left to unravel
# 1206 	 left to unravel
# 1205 	 left to unravel
# 1204 	 left to unravel
# 1203 	 left to unravel
# 1202 	 left to unravel
# 1201 	 left to unravel
# 1200 	 left to unravel
# 1198 	 left to unravel
# 1197 	 left to unravel
# 1196 	 left to unravel
# 1195 	 left to unravel
# 1194 	 left to unravel
# 1193 	 left to unravel
# 1192 	 left to unravel
# 1191 	 left to unravel
# 1190 	 left to unravel
# 1189 	 left to unravel
# 1188 	 left to unravel
# 1187 	 left to unravel
# 1186 	 left to unravel
# 1185 	 left to unravel
# 1184 	 left to unravel
# 1183 	 left to unravel
# 1182 	 left to unravel
# 1181 	 left to unravel
# 1180 	 left to unravel
# 1178 	 left to unravel
# 1177 	 left to unravel
# 1176 	 left to unravel
# 1175 	 left to unravel
# 1174 	 left to unravel
# 1173 	 left to unravel
# 1172 	 left to unravel
# 1171 	 left to unravel
# 1170 	 left to unravel
# 1169 	 left to unravel
# 1168 	 left to unravel
# 1167 	 left to unravel
# 1166 	 left to unravel
# 1165 	 left to unravel
# 1164 	 left to unravel
# 1163 	 left to unravel
# 1162 	 left to unravel
# 1161 	 left to unravel
# 1160 	 left to unravel
# 1159 	 left to unravel
# 1158 	 left to unravel
# 1157 	 left to unravel
# 1156 	 left to unravel
# 1155 	 left to unravel
# 1154 	 left to unravel
# 1153 	 left to unravel
# 1152 	 left to unravel
# 1151 	 left to unravel
# 1150 	 left to unravel
# 1149 	 left to unravel
# 1148 	 left to unravel
# 1147 	 left to unravel
# 1146 	 left to unravel
# 1145 	 left to unravel
# 1144 	 left to unravel
# 1143 	 left to unravel
# 1142 	 left to unravel
# 1141 	 left to unravel
# 1140 	 left to unravel
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:6
#
# Cell In [42], line 11, in get_first_SAW(length, max_tries, debug)
#       9         n_tries +=1
#      10         new_traj = pivot_traj(traj)
# ---> 11         n_intersection = count_self_intersections(new_traj)
#      12 #         if np.mod(ii,100) ==0:
#      13 #             print ('intersection number: \t',n_intersection, '\n and traj is \n', new_traj)
#      14 #         if new intersection number has improved we change path and change our reference # with the new one
#      15         if n_intersection <= n_intersection_ref:
#
# Cell In [31], line 9, in count_self_intersections(traj)
#       6 n_steps_traj = traj.shape[0]
#       8 for i in range(n_steps_traj):
# ----> 9     point_set.add(tuple(traj[i,:]))
#      11 #number of steps of the RW
#      12 n_points_visited = len(point_set)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Exercise 3.14
# Write a function `get_next_SAW` that, given a SAW, generates another SAW using the pivot algorithm. Your function should check that the input RW is really a SAW. Remember the steps:
#
# 1. Apply the pivot transformation
# 2. Check if the new path is self-avoiding. **If so, return it. Otherwise, return the original path.**

# %%
def get_next_SAW(traj,test=False):
    # make sure input traj is SAW
    assert count_self_intersections(traj) == 0
    
    # pivot step
    proposed_traj = pivot_traj(traj)
    
    # count intersections
    num_intersections = count_self_intersections(proposed_traj)
    
    # if it's a SAW
    if num_intersections == 0:
        
        return proposed_traj
    
    #I was curious about the consequences
    elif test:
        return get_next_SAW(traj)
    
    # if not
    else:
        return traj

# %% [markdown]
# ### Mean Squared Displacement in SAW
# A quantity of interest in RWs is the mean squared displacement, which is simply the (squared) distance between the endpoints of the walk. Usually, one writes
#
# $$
# \left\langle X(n)^2 \right\rangle \sim n^{2 \nu}
# $$
#
# As you know, for a standard RW of $n$ steps, the mean-squared displacement scales like $n$, so $\nu=1/2$. However, the exponent for SAW is **different**! Althought it has not been formally proven (still), it is believed that the exponent for SAW is $\nu=3/4$. That is, for a self-avoiding random walk, the mean squared displacement scales as $n^{3/2}$.

# %% [markdown]
# ### Exercise 3.15
# Explain why it makes sense that the mean-squared displacement exponent of SAW is **greater** than that of standard RW.

# %% [markdown]
# Dal momento che un SAW non può ritornare dove è già passato avrà una bassa probabilità di ritornare nei dintorni dell'origine (zona da cui proviene) e tenderà invece ad allontanarsi.
# Per spiegarmi meglio:
# Se consideriamo una circonferenza di raggio $r = n$, il numero dei nodi all'interno di una corona circolare infinitesima compresa tra $r=r_0$ e $r' = r_0 + \Delta n$ sarà proporzionale all'area di tale circonferenza, ovvero proporzionale a
#
# $2\pi r_0$
#
# Si ha dunque che, considerando l'equiprobabilità di tutti i SAW, si tenderà in media a riempire un cerchio di raggio via via maggiore rimbalzando all'esterno ogni qual volta si arriverà ai suoi confini, mentre nel caso di un normale RW il walker potrebbe riattraversarlo liberamente

# %% [markdown]
# ### Exercise 3.16
# Verify numerically the scaling of the mean-squared displacement of SAW. Notice that you don't need to store all the SAWs, just the endpoints. You could follow this scheme:
#
# 1. Generate a first SAW with your `get_first_SAW()` function
# 2. Generate the next SAW using your `get_next_SAW()` function, and store the endpoint.
# 3. Iterate step 2 for as many steps as required
# 4. Compute the average mean-squared displacement of the stored endpoints
#
# Then repeating steps 1-4 for different lengths, and plot the results in double-logarithmic axis. Compare your results with the theoretical exponent. Do they agree?

# %%
def variance_SAW (length, n_SAW = 100,debug = False): 
    """ Compute the varianca of 2-D SAW of given length

        Parameters
        ----------
        length: # of steps of the SARW
        n_SAW : # of different SAW to use to calculate the variance
        
        Returns
        -------
        variance_SAW : Mean Squared value of SARW of length = length averaging n_SAW walks
    """
    start = time.time()
    print('Calculating MS of SAW of Len:\t',length)
    SAW = get_first_SAW(length,debug=False)
    end_point_squared = 0 
    for _ in range(n_SAW):
        SAW = get_next_SAW(SAW,test=False)
        end_point_squared += np.sum(SAW[-1,:]**2)
    
    end = time.time()
    if debug:
        print("The time of execution of above program is :",
            (end-start), "s \n",
         (end-start)/60,"min")
    return end_point_squared/n_SAW

# %%
#length_array = np.arange(1,25)
# define range of RW lengths
length_min = 1
length_max = 10**4
# generate points logarithmically spaces
# and convert them to integers
length_array = np.array([
    int(x)
    for x in np.geomspace(length_min, length_max, num=20)
])
variance_vec = [variance_SAW(length,n_SAW=10000,debug=False) for length in length_array]
# Out:
# Calculating MS of SAW of Len:	 1
# Calculating MS of SAW of Len:	 1
# Calculating MS of SAW of Len:	 2
# Calculating MS of SAW of Len:	 2
# Calculating MS of SAW of Len:	 4
# Calculating MS of SAW of Len:	 6
# Calculating MS of SAW of Len:	 8
# Calculating MS of SAW of Len:	 12
# Calculating MS of SAW of Len:	 18
# Calculating MS of SAW of Len:	 26
# Calculating MS of SAW of Len:	 37
# Calculating MS of SAW of Len:	 54
# Calculating MS of SAW of Len:	 78
# Calculating MS of SAW of Len:	 112
# Calculating MS of SAW of Len:	 162
# Calculating MS of SAW of Len:	 233
# Calculating MS of SAW of Len:	 335
# Calculating MS of SAW of Len:	 483
# Calculating MS of SAW of Len:	 695
# Calculating MS of SAW of Len:	 1000

# %% [markdown]
# ## Plot Mean Squared of a SAW

# %%
# plot the numerical results + theory
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
# plot theoretical result 
#N_returns is approximately the square root of the # of steps
ax.loglog(length_array,
            np.power(length_array,3/2),
            linestyle='dashdot',
            label="Theory")

# plot numerical result
ax.loglog(length_array,
            variance_vec,
            color="orange",
            marker = 'o',
            ms=5,
            linestyle='',
            label="Numerics")
# add axis labels
ax.set_xlabel("$N_{step}$")
ax.set_ylabel(r"$ \left \langle X(n)^2 \right\rangle $")
# add a legend
ax.legend(loc=(0.95, 0.7), frameon=False)

# add a title
ax.set_title(f"Variance of a SAW");
